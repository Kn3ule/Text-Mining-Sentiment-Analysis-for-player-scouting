# %%
import json
import os
import pandas as pd

# %%
# Pfad zum Ordner mit den JSON-Dateien
data_folder = 'data/instagram'

# Leere Liste zur Speicherung aller Kommentare
all_comments = []

# Durchlaufe alle Dateien im Ordner "data"
for filename in os.listdir(data_folder):
    if filename.endswith(".json"):
        filepath = os.path.join(data_folder, filename)
        
        # Vereinsname aus dem Dateinamen extrahieren (z.B. "verein1.json" -> "verein1")
        club_name = os.path.splitext(filename)[0].replace('_instacomments', '')

        # Öffne die JSON-Datei und lade den Inhalt
        with open(filepath, 'r', encoding='utf-8') as f:
            posts = json.load(f)

            # Falls das JSON eine Liste von Posts ist
            if isinstance(posts, list):
                # Extrahiere die Kommentare aus jedem Post
                for post in posts:
                    if 'comments' in post:
                        for comment in post['comments']:
                            all_comments.append({
                                'verein': club_name,  # Name des Vereins aus der Datei
                                'post': post.get('link', ''),  # Link zum Post (falls vorhanden)
                                'caption': post.get('caption', ''),  # Post-Caption (falls vorhanden)
                                'comment': comment,  # Kommentar-Text
                            })
            # Falls das JSON keine Liste ist (z.B. einzelne Posts)
            elif 'comments' in posts:
                # Extrahiere die Kommentare aus dem einzelnen Post
                for comment in posts['comments']:
                    all_comments.append({
                        'verein': club_name,  # Name des Vereins aus der Datei
                        'post': posts.get('link', ''),  # Link zum Post (falls vorhanden)
                        'caption': posts.get('caption', ''),  # Post-Caption (falls vorhanden)
                        'comment': comment,  # Kommentar-Text
                    })

# Speichern aller Kommentare in einem Pandas DataFrame
df = pd.DataFrame(all_comments)

df = df[~df['comment'].str.contains("Original-Audio", case=False, na=False)]
df = df[~df['comment'].str.contains("•", case=False, na=False)]

df = df.drop_duplicates(subset=['comment'])

df
# Out:
#                verein                                         post  \
# 0       staderennesfc     https://www.instagram.com/p/C8e7U9jAc5P/
# 1       staderennesfc     https://www.instagram.com/p/C8e7U9jAc5P/
# 2       staderennesfc     https://www.instagram.com/p/C8e7U9jAc5P/
# 3       staderennesfc     https://www.instagram.com/p/C8e7U9jAc5P/
# 4       staderennesfc     https://www.instagram.com/p/C8e7U9jAc5P/
# ...               ...                                          ...
# 117884      fcchelsea  https://www.instagram.com/reel/DAePCASsGvm/
# 117885      fcchelsea  https://www.instagram.com/reel/DAePCASsGvm/
# 117886      fcchelsea  https://www.instagram.com/reel/DAePCASsGvm/
# 117889      fcchelsea  https://www.instagram.com/reel/DAePCASsGvm/
# 117891      fcchelsea  https://www.instagram.com/reel/DAePCASsGvm/
#
#                                                   caption  \
# 0       Brest puis Nantes, les affiches des derbies po...
# 1       Brest puis Nantes, les affiches des derbies po...
# 2       Brest puis Nantes, les affiches des derbies po...
# 3       Brest puis Nantes, les affiches des derbies po...
# 4       Brest puis Nantes, les affiches des derbies po...
# ...                                                   ...
# 117884  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
# 117885  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
# 117886  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
# 117889  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
# 117891  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
#
#                                                   comment
# 0       On est 1 point devant les relégables, on perd ...
# 1       Mm notre équipe amicale est meilleure que vous...
# 2       Ppl need to stop supporting this match fixing ...
# 3                                          Match fixedddd
# 4       Just investigate you will find lots of very co...
# ...                                                   ...
# 117884                                   Innit star boy 🥶
# 117885                                                🙌🙌🥶
# 117886                                                🪄 💙
# 117889                              love you bro always💙🤍
# 117891  Next game cole. I need 5 goals from you man @c...
#
# [85088 rows x 4 columns]

# %%
posts_per_club = df.groupby('verein')['post'].nunique().reset_index()
posts_per_club.columns = ['Verein', 'Anzahl_Posts']

comments_per_club = df.groupby('verein')['comment'].count().reset_index()
comments_per_club.columns = ['Verein', 'Anzahl_Kommentare']

comments_per_club['avg_comments_per_post'] = comments_per_club['Anzahl_Kommentare'] / posts_per_club['Anzahl_Posts']


summary_df = pd.merge(posts_per_club, comments_per_club[['Verein', 'Anzahl_Kommentare', 'avg_comments_per_post']], on='Verein')

summary_df
# Out:
#            Verein  Anzahl_Posts  Anzahl_Kommentare  avg_comments_per_post
# 0         arsenal           239               3063              12.815900
# 1            avfc           156               2871              18.403846
# 2         bayer04           240               5863              24.429167
# 3             bvb           229               3292              14.375546
# 4        fcbayern            59               4895              82.966102
# 5       fcchelsea            19              10232             538.526316
# 6             fch           225               2301              10.226667
# 7         ipswich           107               1043               9.747664
# 8           lille            71               1729              24.352113
# 9     liverpoolfc           126              15148             120.222222
# 10        mancity           132               1350              10.227273
# 11         rclens           187               3314              17.721925
# 12   realsociedad           232               7642              32.939655
# 13      sevillafc           202               2246              11.118812
# 14  staderennesfc           238               2020               8.487395
# 15            vfb           120               9104              75.866667
# 16   villarrealcf           238               8975              37.710084

# %% [markdown]
# # Data Preprocessing
#
# * language detection for all comments
# * select only comments in german, english, french or spanish
# * preprocessing:
#     1. remove all mentions (e.g. see here @user) in
#     2. switch the emoji to text
#     3. lower case

# %%
import emoji
import re
from langdetect import detect, DetectorFactory
import spacy
from spacy_langdetect import LanguageDetector

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TFAutoModelForSequenceClassification
import tensorflow as tf

# Laden des Tokenizers und des TensorFlow-Modells
tokenizer = AutoTokenizer.from_pretrained("papluca/xlm-roberta-base-language-detection")
model = TFAutoModelForSequenceClassification.from_pretrained("papluca/xlm-roberta-base-language-detection")

# Labels des Modells abrufen
labels = model.config.id2label

def detect_language_transformers(text):
    # Tokenisierung des Textes
    inputs = tokenizer(text, return_tensors="tf", truncation=True)
    # Modellvorhersage
    outputs = model(**inputs)
    # Vorhersagewahrscheinlichkeiten
    logits = outputs.logits
    predicted_class_id = tf.argmax(logits, axis=-1).numpy()[0]
    language = labels[predicted_class_id]
    return language
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFXLMRobertaForSequenceClassification: ['roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFXLMRobertaForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFXLMRobertaForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFXLMRobertaForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFXLMRobertaForSequenceClassification for predictions without further training.

# %%
# Anwenden der Spracherkennungsfunktion
df['language'] = df['comment'].apply(detect_language_transformers)

# %%
df.to_csv('comments_with_language.csv')

# %%
# Definieren Sie die gewünschten Sprachcodes
allowed_languages = ['de', 'en', 'es', 'fr']

# Filtern des DataFrames
df_allowed_languages = df[df['language'].isin(allowed_languages)].reset_index(drop=True)

# %%
language_counts = df_allowed_languages["language"].value_counts()
print(language_counts)
# Out:
# language
# en    26755
# de    10923
# es     6214
# fr     2627
# Name: count, dtype: int64

# %%
df_allowed_languages.to_csv("comments_with_allowed_language.csv")

# %%
posts_per_club = df_allowed_languages.groupby('verein')['post'].nunique().reset_index()
posts_per_club.columns = ['Verein', 'Anzahl_Posts']

comments_per_club = df_allowed_languages.groupby('verein')['comment'].count().reset_index()
comments_per_club.columns = ['Verein', 'Anzahl_Kommentare']

comments_per_club['avg_comments_per_post'] = comments_per_club['Anzahl_Kommentare'] / posts_per_club['Anzahl_Posts']


summary_df = pd.merge(posts_per_club, comments_per_club[['Verein', 'Anzahl_Kommentare', 'avg_comments_per_post']], on='Verein')

summary_df
# Out:
#             Verein  Anzahl_Posts  Anzahl_Kommentare  avg_comments_per_post
# 0          arsenal           237               1867               7.877637
# 1             avfc           156               1979              12.685897
# 2          bayer04           237               3082              13.004219
# 3              bvb           224               1866               8.330357
# 4         fcbayern            59               2771              46.966102
# 5        fcchelsea            19               6599             347.315789
# 6              fch           221               1741               7.877828
# 7          ipswich           105                593               5.647619
# 8            lille            70               1051              15.014286
# 9      liverpoolfc           125               8958              71.664000
# 10         mancity           132                674               5.106061
# 11          rclens           137                616               4.496350
# 12    realsociedad           200               2143              10.715000
# 13       sevillafc           202               1412               6.990099
# 14  staderennaisfc           226               1239               5.482301
# 15             vfb           120               6455              53.791667
# 16    villarrealcf           227               3473              15.299559

# %%
def remove_mentions(text):
    return re.sub(r'@\w+', '', text)

# %%
def convert_emojis_to_text(text, lang):
    # Verwenden von Leerzeichen als Trennzeichen
            return emoji.demojize(text, language=lang, delimiters=(" ", " "))

# %%
def clean_comment(text):
    text = remove_mentions(text)
    text = convert_emojis_to_text(text)
    return text

# %%
def clean_text(text):
    text = text.lower()
    text = text.replace(':', '')
    text = text.replace('_', ' ')
    text = ' '.join(text.split())
    return text

# %%
def preprocess_comment(row):
    text = row['comment']
    language = row['language']
    # Entfernen von Mentions
    text = remove_mentions(text)
    # Konvertieren von Emojis
    text = convert_emojis_to_text(text, language)
    # Text bereinigen
    text = clean_text(text)
    return text

# %%
preprocessed_df = pd.read_csv('comments_with_allowed_language.csv')

preprocessed_df["comment_cleaned"] = preprocessed_df.apply(preprocess_comment, axis=1)

# %%
preprocessed_df
# Out:
#        Unnamed: 0          verein  \
# 0               0  staderennaisfc
# 1               1  staderennaisfc
# 2               2  staderennaisfc
# 3               3  staderennaisfc
# 4               4  staderennaisfc
# ...           ...             ...
# 46514       46514       fcchelsea
# 46515       46515       fcchelsea
# 46516       46516       fcchelsea
# 46517       46517       fcchelsea
# 46518       46518       fcchelsea
#
#                                               post  \
# 0         https://www.instagram.com/p/C8e7U9jAc5P/
# 1         https://www.instagram.com/p/C8e7U9jAc5P/
# 2         https://www.instagram.com/p/C8e7U9jAc5P/
# 3         https://www.instagram.com/p/C8e7U9jAc5P/
# 4         https://www.instagram.com/p/C8e7U9jAc5P/
# ...                                            ...
# 46514  https://www.instagram.com/reel/DAePCASsGvm/
# 46515  https://www.instagram.com/reel/DAePCASsGvm/
# 46516  https://www.instagram.com/reel/DAePCASsGvm/
# 46517  https://www.instagram.com/reel/DAePCASsGvm/
# 46518  https://www.instagram.com/reel/DAePCASsGvm/
#
#                                                  caption  \
# 0      Brest puis Nantes, les affiches des derbies po...
# 1      Brest puis Nantes, les affiches des derbies po...
# 2      Brest puis Nantes, les affiches des derbies po...
# 3      Brest puis Nantes, les affiches des derbies po...
# 4      Brest puis Nantes, les affiches des derbies po...
# ...                                                  ...
# 46514  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
# 46515  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
# 46516  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
# 46517  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
# 46518  Three points, four goals. 🗣️👊#CHEBHA #CFC #Che...
#
#                                                  comment language  \
# 0      On est 1 point devant les relégables, on perd ...       fr
# 1      Mm notre équipe amicale est meilleure que vous...       fr
# 2      Ppl need to stop supporting this match fixing ...       en
# 3                                         Match fixedddd       en
# 4      Just investigate you will find lots of very co...       en
# ...                                                  ...      ...
# 46514                           Bro you are a genius 🥶💙🔥       en
# 46515  This dude caused Earthquake and Volcano Erupti...       en
# 46516           Our fellow African bro you're genius 🔥🔥🔥       en
# 46517                              love you bro always💙🤍       en
# 46518  Next game cole. I need 5 goals from you man @c...       en
#
#                                          comment_cleaned
# 0      on est 1 point devant les relégables, on perd ...
# 1      mm notre équipe amicale est meilleure que vous...
# 2      ppl need to stop supporting this match fixing ...
# 3                                         match fixedddd
# 4      just investigate you will find lots of very co...
# ...                                                  ...
# 46514     bro you are a genius cold face blue heart fire
# 46515  this dude caused earthquake and volcano erupti...
# 46516  our fellow african bro you're genius fire fire...
# 46517         love you bro always blue heart white heart
# 46518  next game cole. i need 5 goals from you man bl...
#
# [46519 rows x 7 columns]

# %%
import json
import unidecode
from rapidfuzz import process, fuzz
from collections import defaultdict

# Laden der Vereine und Spieler aus Ihrer JSON-Datei
with open('player.json', 'r', encoding='utf-8') as f:
    clubs_data = json.load(f)

def preprocess_name(name):
    if not isinstance(name, str):
        print(f"Warnung: Erwarteter String, aber erhalten: {type(name)}")
        return ''
    name = unidecode.unidecode(name)
    name = name.lower()
    name = ''.join(e for e in name if e.isalnum() or e.isspace())
    return name

clubs_players_processed = {}

for club_entry in clubs_data["clubs"]:
    club_name = club_entry['club_name']
    players = club_entry['players']
    preprocessed_players = [preprocess_name(player) for player in players]
    clubs_players_processed[club_name.lower()] = preprocessed_players


def preprocess_comment(comment):
    if not isinstance(comment, str):
        print(f"Warnung: Erwarteter String, aber erhalten: {type(comment)}")
        return ''
    comment = unidecode.unidecode(comment)
    comment = ''.join(e for e in comment if e.isalnum() or e.isspace())
    return comment

#preprocessed_df['comment_processed'] = preprocessed_df['comment_cleaned'].apply(preprocess_comment)
df['comment_processed'] = df['comment'].apply(preprocess_comment)

def find_players_in_comment(comment, player_names, threshold=80):
    matches = process.extract(
        comment, player_names, scorer=fuzz.partial_ratio, score_cutoff=threshold
    )
    return [match[0] for match in matches]

def assign_comments_to_players(df, clubs_players):
    results = {'clubs': []}
    
    # Gruppieren des DataFrames nach Verein
    grouped = df.groupby('verein')
    
    for club_name, group in grouped:
        club_name_lower = club_name.lower()
        if club_name_lower in clubs_players:
            player_names = clubs_players[club_name_lower]
            # Finden der Originalspieler
            original_players = next(
                (club['players'] for club in clubs_data['clubs'] if club['club_name'].lower() == club_name_lower),
                []
            )
            club_result = {
                'club_name': club_name,
                'players': []
            }
            player_comments_dict = defaultdict(list)
            
            for index, row in group.iterrows():
                #comment = row['comment_cleaned']
                comment = row['comment']
                comment_processed = row['comment_processed']
                
                # Spieler im Kommentar finden
                matched_players = find_players_in_comment(comment_processed, player_names)
                
                # Kommentare den Spielern zuordnen
                for player in matched_players:
                    # Finden des Originalspielernamens
                    idx = player_names.index(player)
                    original_player_name = original_players[idx]
                    player_comments_dict[original_player_name].append(comment)
            
            # Spieler und ihre Kommentare hinzufügen
            for player_name, comments in player_comments_dict.items():
                club_result['players'].append({
                    'player_name': player_name,
                    'comments': comments
                })
            
            results['clubs'].append(club_result)
    
    return results

# Anwenden der Funktion
results = assign_comments_to_players(df, clubs_players_processed)

# Speichern der Ergebnisse in einer JSON-Datei
with open('player_comments.json', 'w', encoding='utf-8') as f:
    json.dump(results, f, ensure_ascii=False, indent=4)

# Ausgabe zur Überprüfung
print(json.dumps(results, ensure_ascii=False, indent=4))
# Out:
# {
#     "clubs": [
#         {
#             "club_name": "arsenal",
#             "players": [
#                 {
#                     "player_name": "Ben White",
#                     "comments": [
#                         "Happy Birthday Ben White❤️",
#                         "ben🎉💯",
#                         "Happy birthday Ben white we actually share birthday mehn",
#                         "More life Benny white white white 😍😍🔥",
#                         "Ben white I love you ❤️😘",
#                         "Happy birthday Mr white...❤️❤️❤️",
#                         "Happy birthday Benjamin white 👏👏👏",
#                         "Oh Benny my most favorite Arsenal player, just does the job and moves on. Oh I love you incredible Ben white ❤️❤️❤️❤️",
#                         "تاااا",
#                         "🦁 💪🏾",
#                         "🔥🔥🔥 🔥🔥🔥",
#                         "Where is white",
#                         "👏👏👏👏👏 🇧🇷🇧🇷🇧🇷🇧🇷",
#                         "هع🔥🔥",
#                         "🔥 🔥🔥🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Gabriel Martinelli",
#                     "comments": [
#                         "🤫🧏‍♂️ @gabriel.martinelli",
#                         "Martinelli❤️🔥",
#                         "Gabriel 👏👏",
#                         "Gabriel",
#                         "Vintage Gabriel Martinelli ™️",
#                         "😂😂😂😂 martinelli",
#                         "🪽Gabriel",
#                         "At the front Gabriel Martinellie, Jessu and Saka😍"
#                     ]
#                 },
#                 {
#                     "player_name": "Jurrien Timber",
#                     "comments": [
#                         "تاااا",
#                         "Timber🧱",
#                         "🦁 💪🏾",
#                         "🔥🔥🔥 🔥🔥🔥",
#                         "👏👏👏👏👏 🇧🇷🇧🇷🇧🇷🇧🇷",
#                         "🔥 🔥🔥🔥",
#                         "A message from Jurrien Timber",
#                         "@jurrientimber you’re a joy to watch… so much versatility and confidence 🔥🔥",
#                         "Timber😂"
#                     ]
#                 },
#                 {
#                     "player_name": "Thomas Partey",
#                     "comments": [
#                         "تاااا",
#                         "🔥🙌🔥Thomas partey was good today 👏",
#                         "هع🔥🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Martin Odegaard",
#                     "comments": [
#                         "تاااا",
#                         "@odegaard.98 😂😂",
#                         "Hard💥",
#                         "Odegaard🩷🩷",
#                         "We miss you Martin Ordergaad",
#                         "Martin odegrad🙌",
#                         "Let's play regular centre half in the middle Decland Rice, Leandro Trossard, Martin Odegaar 😋"
#                     ]
#                 },
#                 {
#                     "player_name": "Kai Havertz",
#                     "comments": [
#                         "تاااا",
#                         "Havertz 👏🔥👑🙌👍😎💯💪💪💪💪💪",
#                         "Zaminamina eh eh waka waka eh eh 60 million down the drain Kai haverts scores again",
#                         "Havertz🔥",
#                         "What a wonderful game it was⭐⭐⭐⭐⭐ truth. Is all frwds matineli Saka harverts trosaard are all on form",
#                         "Kai Havertz scores again 🎶",
#                         "Havertz",
#                         "❤️❤️❤️ Kai Havertz",
#                         "Thanks @kaihavertz29",
#                         "Kai Havertz POTM",
#                         "👑kai",
#                         "Kai Havertz scoring his first Arsenal goal 🥰",
#                         "That was one of my most emotional games ever cuz trossard, martinelli and havertz are my favs😢👏",
#                         "Arteta need to learn..we can’t be watching kai Havertz for the whole useless90min",
#                         "Havertz 🔥🔥",
#                         "🎶 Kai Havertz scored again 🎶",
#                         "هع🔥🔥",
#                         "Kai havertz tackling Ruben Dias, true passion",
#                         "Joachim low era el dt señores , son un equipo junior tienen miedo a atacar al veces estoy viendo el partido havertz no esta para el arsenal,  recogen sobras de otro club. Vayan por wirtz musiala , mghalaes no es un buen central"
#                     ]
#                 },
#                 {
#                     "player_name": "David Raya",
#                     "comments": [
#                         "Raya🔝",
#                         "Kaya!!!",
#                         "Raya🙌",
#                         "David raya on top best man for me",
#                         "Raya",
#                         "David raya",
#                         "David raya..first line..🔥🔥",
#                         "david raya looks like cihuahua",
#                         "🦁 💪🏾",
#                         "🔥🔥🔥 🔥🔥🔥",
#                         "👏👏👏👏👏 🇧🇷🇧🇷🇧🇷🇧🇷",
#                         "David Raya 🧤",
#                         "🔥 🔥🔥🔥",
#                         "I Love you David ❤️Raya❤️😍",
#                         "🔥 we're supposed to said thanks 🙏 to you our best goalkeeper David Raya"
#                     ]
#                 },
#                 {
#                     "player_name": "William Saliba",
#                     "comments": [
#                         "Saliba🔥🔥",
#                         "Saliba",
#                         "The challenge. The roar. William Saliba 💪",
#                         "Saliba 😘💞💞",
#                         "🦁 💪🏾",
#                         "🔥🔥🔥 🔥🔥🔥",
#                         "👏👏👏👏👏 🇧🇷🇧🇷🇧🇷🇧🇷",
#                         "🔥 🔥🔥🔥",
#                         "Saliba 🔥",
#                         "saliba 😂❤️",
#                         "I just love William Saliba energy he brings to this arsenal team. He makes every player on this arsenal want to score a goal and have him celebrate with them.💪💪",
#                         "🛡️ William Saliba 🛡️"
#                     ]
#                 },
#                 {
#                     "player_name": "Oleksandr Zinchenko",
#                     "comments": [
#                         "🦁 💪🏾",
#                         "🔥🔥🔥 🔥🔥🔥",
#                         "👏👏👏👏👏 🇧🇷🇧🇷🇧🇷🇧🇷",
#                         "هع🔥🔥",
#                         "🔥 🔥🔥🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Declan Rice",
#                     "comments": [
#                         "Let's play regular centre half in the middle Decland Rice, Leandro Trossard, Martin Odegaar 😋"
#                     ]
#                 }
#             ]
#         },
#         {
#             "club_name": "avfc",
#             "players": [
#                 {
#                     "player_name": "Leon Bailey",
#                     "comments": [
#                         "Duran x philogene o bailey",
#                         "i",
#                         "A bet unu nuh see the touch 🥶🥶 @leonbailey ute u nuh normal inu",
#                         "Bailey ❤️❤️🔥🔥🫡🫡",
#                         "Why is leon bailey playing like one of them",
#                         "🔥🔥one Bailey"
#                     ]
#                 },
#                 {
#                     "player_name": "Ollie Watkins",
#                     "comments": [
#                         "Du Du Du..du Olie watkins.. DuDuDy du",
#                         "Better than Ollie Watkins",
#                         "Answer me one question Villa fans. Will Ollie Watkins have a shot on target or not?",
#                         "Aaron Love ❤️ Ollie Watkins",
#                         "Did Ollie Watkins leave Nike for adidas?",
#                         "Goooooooo my love 👼🏻🏹💘 Ollie Watkins @olliewatkins",
#                         "Ollie watckins🔥",
#                         "Ollie🔥🔥🔥",
#                         "Lol",
#                         "Watkins?",
#                         "Lest go @olliewatkins ⚽️🚀"
#                     ]
#                 },
#                 {
#                     "player_name": "Emiliano Martinez",
#                     "comments": [
#                         "Emiliano Martínez te amo❤️❤️🔥",
#                         "i",
#                         "Duran &martinez🔥🔥",
#                         "emi🙌❤️",
#                         "❄️ 😂",
#                         "Emiliano martinez to Barcelona here we go ❤️💙"
#                     ]
#                 },
#                 {
#                     "player_name": "Pau Torres",
#                     "comments": [
#                         "Pau tores should be our captain.",
#                         "❄️ 😂",
#                         "Yes."
#                     ]
#                 },
#                 {
#                     "player_name": "Diego Carlos",
#                     "comments": [
#                         "Diego Carlos what a man!! Not great at the weekend and turns up and does that!!! #utv",
#                         "i",
#                         "Carlos 😢",
#                         "Mad he keeps playing carlos",
#                         "diego carlos was not up to par😢😢😢",
#                         "❄️ 😂",
#                         "Bench diego carlos",
#                         "I blame Diego Carlos for the goal we conceded"
#                     ]
#                 },
#                 {
#                     "player_name": "Jacob Ramsey",
#                     "comments": [
#                         "Here is why Villa beat Bayern Villa beat Bayern 1-0, 42 years after they last beat them 1-0 The beast of revelation reigns for 42 monthsEnglish team vs German team World War = 42War = 42Villa beat Bayern in 1982, which was the same year as the Falklands War between Argentina and the UK, which began on 4/2, and at the death Argentine Martinez made a game winning save vs Englishman Harry Kane, who was born exactly 79 years after WW1 began and Duran scored the winning goal today after 79 minsThe game ended 1-0 and the Falkland’s War lasted 10 weeks I think this is why Villa “shocked” Bayern last night.Villa’s opening game of the 2024-2025 UCL was on 17/9 (41st prime) #41 Jacob Ramsey came off injured for Villa after 27 minsVillains goalkeeper Emi Martinez won the 2022 FIFA World Cup and Golden Gloves award and the 2022 FIFA World Cup began with 41 days left in the yearIt was 9th vs 11th and 9/11 was on 41DN pure 9+11+20+0+1 = 41Bayern were undefeated in 41 games vs English sidesBayern were undefeated in 41 group stage/now league stage gamesThis is Villa’s first season in the Champions League (European Cup) after 41 yearsJhon Duran scored the winner in his 41st for Villa41 is the 13th prime Jhon was born on the 13th of December (Sam birthday as Taylor Swift, who’s fav number is 13)It was his 13th goal for VillaHis initials are JJDP JJDP = 13 13 is the 6th prime Villa advanced to 6 points in the group",
#                         "Jacob 😍😍😍",
#                         "@jacobramseyy 😍😍😍",
#                         "frame",
#                         "Don’t understand why we have turned up with only Jacob Ramsey that can really make an impact off the bench",
#                         "@jacobramseyy  bro ❤️"
#                     ]
#                 },
#                 {
#                     "player_name": "Lucas Digne",
#                     "comments": [
#                         "i",
#                         "@lucasdigne congratulations and we need ANOTHER ONNNNNNEEEE",
#                         "❄️ 😂"
#                     ]
#                 },
#                 {
#                     "player_name": "Ian Maatsen",
#                     "comments": [
#                         "i",
#                         "Konsa back to center half! Maatsen  play as right back!!! Get both Digne and Maatsen to swap during game! Defensive wide players should learn to be much more flexible as professional players . Too much  made of left  foot right foot!  Always work on ur weaknesses!!!!",
#                         "Who was with Kamara and Maatsen?",
#                         "❄️ 😂",
#                         "Anyone else notice the commentator keep getting young and Maatsen mixed up 🤨"
#                     ]
#                 },
#                 {
#                     "player_name": "Morgan Rogers",
#                     "comments": [
#                         "Morgan rogers doesn’t get enough talk I swear he’s too cold",
#                         "I thought it was Morgan Sanson, it turned out to be Morgan Rogers🤣"
#                     ]
#                 }
#             ]
#         },
#         {
#             "club_name": "bayer04",
#             "players": [
#                 {
#                     "player_name": "Florian Wirtz",
#                     "comments": [
#                         "Florian❤️❤️❤️❤️",
#                         "Wirtz 🔥",
#                         "Floryan wirtz",
#                         "Congratulations, dear Florian Wirtz.",
#                         "Florian 🎩⚽",
#                         "dai wirtz",
#                         "wirtz",
#                         "Florian Wirtz and 10 more 🗑️",
#                         "🔥👏 flowirtz.",
#                         "You are the best Florian wirtz 🔥",
#                         "Wirtz 😍",
#                         "Wirtz❤️🙌",
#                         "Wirtz🔥🔥🔥🔥",
#                         "Florian Wirtzard",
#                         "Wirtz🥶",
#                         "Florian Wirtz ❤️",
#                         "❤️wirtz"
#                     ]
#                 },
#                 {
#                     "player_name": "Robert Andrich",
#                     "comments": [
#                         "❤️Ahhhhhh!  Robert Andrich is such a cool 😎 man.",
#                         "Ladri",
#                         "Robert Andrich als Man of the match zu ernennen, ist ja mal so frech. Leverkusen ihr lauft so an der Realität vorbei. Ihr werdet kein Meister mit dieser Spielweise😘☝🏼",
#                         "Robert Andrich Fußballgott!! 🖤❤️🔥💪",
#                         "Roberto Candrich",
#                         "best 🔥🙌",
#                         "Robert Andrich Fußballgott!!!",
#                         "Bro"
#                     ]
#                 },
#                 {
#                     "player_name": "Victor Boniface",
#                     "comments": [
#                         "Where is my mentor @boniface_jrn pics",
#                         "Boniface 🤣",
#                         "Bonifacey 🙌🙌",
#                         "Bonifacey 😂😂😂",
#                         "Obaniface🔥🔥🇳🇬🇳🇬🇳🇬",
#                         "bornifacey",
#                         "Bonifacey🦅",
#                         "Boniface 🇳🇬",
#                         "bonifacey😂😂😂",
#                         "This handler is in love with boniface",
#                         "Bonifacey😂😂😂",
#                         "is this odumodu or boniface",
#                         "Bonifacey",
#                         "Boniface 😂❤️",
#                         "Bonifacey 😂😂",
#                         "bonifacey 😂",
#                         "Boniface 🇳🇬🫶",
#                         "Boniface??",
#                         "Boniface...",
#                         "Boniface 🇳🇬🦅❤️🔥🔥🔥🔥",
#                         "Boniface",
#                         "🔥🔥🔥Victor🔥🔥🔥",
#                         "boniface",
#                         "Boniface🔥",
#                         "Boniface!!!!",
#                         "Boniface 💪🏾🦅🇳🇬",
#                         "Bonifacey 🤣",
#                         "Boniface🔥🔥",
#                         "Boniface ❤️🤣",
#                         "See boni face😂",
#                         "😂😂😂 @boniface_jrn 👏",
#                         "Boniface😂😂😂😂",
#                         "Boni face🇳🇬😍😂😂😂",
#                         "Victor Boniface 🇳🇬🔥😍",
#                         "Boniface 😂😂",
#                         "Wow ….Victor Boniface 🔥🔥🇳🇬🇳🇬👏👏",
#                         "Bonifacy",
#                         "Boni face 😂😂😂😂😂",
#                         "Boniface 🔥🔥🔥",
#                         "Face😂🔥",
#                         "BoniFace",
#                         "😂😂 boni",
#                         "Victor Boniface🔥🔥",
#                         "Make I just wait for boniface caption 😂",
#                         "Victor Boniface 🔥 @boniface_jrn",
#                         "Boniface 🙌🏾💪🏽",
#                         "Boniface 😂😂😂",
#                         "Victor 🔥🔥🔥",
#                         "Boniface 🔥🙌❤️",
#                         "Passe do boniface🔥",
#                         "Boniface 🚀🌎🌌",
#                         "Victor 🙌🙌🙌🔥🔥🇳🇬🇳🇬",
#                         "Mukiele or boniface",
#                         "Boniface 🔥🔥🔥🔥",
#                         "Boniface❤️❤️❤️",
#                         "@boniface_jrn 🔥🔥🔥",
#                         "“Victor Boniface”, present ✅",
#                         "😂😂😂😂😂😂victor o"
#                     ]
#                 },
#                 {
#                     "player_name": "Matej Kovar",
#                     "comments": [
#                         "👏👏👏👏 🖤❤️",
#                         "❤️ 🇳🇬",
#                         "🇳🇬 .😜!!!",
#                         "👏👏👏👏 ❤️🖤",
#                         "😂😂😂😂 👏👏👏",
#                         "🇳🇬 🔥🔥",
#                         "🚌 🚍",
#                         "😍😍😍 🖤❤️",
#                         "🔥🔥🔥 💯",
#                         "🔥🔥 🔥🔥🔥🔥🔥🔥🔥🔥🔥",
#                         "Where Matěj Kovář"
#                     ]
#                 },
#                 {
#                     "player_name": "Lukas Hradecky",
#                     "comments": [
#                         "👏👏👏👏 🖤❤️",
#                         "❤️ 🇳🇬",
#                         "🇳🇬 .😜!!!",
#                         "👏👏👏👏 ❤️🖤",
#                         "😂😂😂😂 👏👏👏",
#                         "🇳🇬 🔥🔥",
#                         "🚌 🚍",
#                         "🧱 Hradecky 🕸️",
#                         "😍😍😍 🖤❤️",
#                         "🔥🔥🔥 💯",
#                         "🔥🔥 🔥🔥🔥🔥🔥🔥🔥🔥🔥",
#                         "Lukas hradecky"
#                     ]
#                 },
#                 {
#                     "player_name": "Edmond Tabsoba",
#                     "comments": [
#                         "👏👏👏👏 🖤❤️",
#                         "❤️ 🇳🇬",
#                         "🇳🇬 .😜!!!",
#                         "👏👏👏👏 ❤️🖤",
#                         "😂😂😂😂 👏👏👏",
#                         "🇳🇬 🔥🔥",
#                         "🚌 🚍",
#                         "😍😍😍 🖤❤️",
#                         "@edmondtapsoba Wow, aber was für ein hübscher, großartiger Kopfschuss🖤❤️💪👏🙌🔥🔥🔥",
#                         "Edmond❤️❤️❤️",
#                         "🔥🔥🔥 💯",
#                         "🔥🔥 🔥🔥🔥🔥🔥🔥🔥🔥🔥",
#                         "Edmond🇧🇫🇧🇫"
#                     ]
#                 },
#                 {
#                     "player_name": "Piero Hincapie",
#                     "comments": [
#                         "👏👏👏👏 🖤❤️",
#                         "@pierohincapie 👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼🙏",
#                         "😍Piero",
#                         "Hincapié 👏🇪🇨🇪🇨🇪🇨",
#                         "@pierohincapie 🙌💜👏",
#                         "Yo en piero hincapie siento una vibra muy positiva dentro de cancha y afuera de las canchas ♥️",
#                         "Piero 😍",
#                         "❤️ 🇳🇬",
#                         "🇳🇬 .😜!!!",
#                         "La Muralla de Ecuador Piero Hincapié 🇪🇨🔥",
#                         "👏👏👏👏 ❤️🖤",
#                         "Piero🔥",
#                         "😂😂😂😂 👏👏👏",
#                         "🇳🇬 🔥🔥",
#                         "@pierohincapie war der beste",
#                         "@sie",
#                         "🚌 🚍",
#                         "😍😍😍 🖤❤️",
#                         "Piero 🔥",
#                         "Hincapié 🔥🔥🔥🔥🔥",
#                         "pai",
#                         "@pierohincapie 💜👏🇪🇨",
#                         "Piero🇪🇨💪🏻💪🏻🇪🇨🇪🇨🇪🇨🇪🇨🇪🇨🇪🇨",
#                         "🔥🔥🔥 💯",
#                         "Piero 👏❤️🖤",
#                         "@pierohincapie 👏💜🇪🇨",
#                         "🔥🔥 🔥🔥🔥🔥🔥🔥🔥🔥🔥",
#                         "@pierohincapie 💜👏🙌🇪🇨",
#                         "Piero Hincapié 😍",
#                         "Piero 😍👏👏",
#                         "Made in Ecuador 🇪🇨 Piero hincapie .",
#                         "Piero?"
#                     ]
#                 },
#                 {
#                     "player_name": "Jonathan Tah",
#                     "comments": [
#                         "👏👏👏👏 🖤❤️",
#                         "❤️ 🇳🇬",
#                         "🇳🇬 .😜!!!",
#                         "👏👏👏👏 ❤️🖤",
#                         "😂😂😂😂 👏👏👏",
#                         "🇳🇬 🔥🔥",
#                         "Ahan !!!!",
#                         "🚌 🚍",
#                         "😍😍😍 🖤❤️",
#                         "🔥🔥🔥 💯",
#                         "🔥🔥 🔥🔥🔥🔥🔥🔥🔥🔥🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Alejandro Grimaldo",
#                     "comments": [
#                         "Grimaldi🤎",
#                         "Goat grimaldo",
#                         "Grimaldo ❤️🙌"
#                     ]
#                 },
#                 {
#                     "player_name": "Granit Xhaka",
#                     "comments": [
#                         "Xhaka🔥🔥",
#                         "@granitxhaka unser Löwe unsere Festung 👑 ❤️🖤",
#                         "xhakabommm 🔥❤️ @granitxhaka",
#                         "Xhaka 🔥",
#                         "The best Garanit Xhaka",
#                         "@granitxhaka 👌",
#                         "Granit 🔥🔥🔥🔥🔥🔥",
#                         "@granitxhaka  Alles gute zum Geburtstag 🎂",
#                         "@granitxhaka 😍🔥❤️ LEADER",
#                         "Xhaka?",
#                         "Granit Xhaka bleibt eine Legende 🙌",
#                         "Granit",
#                         "@granitxhaka ❤️🖤😍",
#                         "The pass from @granitxhaka is artistic too 🔥"
#                     ]
#                 }
#             ]
#         },
#         {
#             "club_name": "bvb",
#             "players": [
#                 {
#                     "player_name": "Emre Can",
#                     "comments": [
#                         "Irgendwie hat er nen Antritt wie Emre Can🤓",
#                         "Can",
#                         "Emre can wie kann so einer Kapitän sein der schlechteste Mittelfeld spieler in der BL ein sabitzer sitzt 75 Minuten auf der bank schlotterbeck grauenhaft couto auch echt nicht gut dieses spiel dann kommt ein bensebaini rein der absolut schlecht ist schon seit dem er bei Dortmund ist beier auch echt nicht gut also und das schlimmste ist keiner außer ryerson und guirassy hat versucht zu kämpfen",
#                         "New Goat🖤💛 @emrecan23",
#                         "🖤💛 🍀",
#                         "⚡ 🇧🇷🖤💛",
#                         "🖤💛 🫶",
#                         "ن",
#                         "bitte groß auf 6 sabi auf 8 und emre can linke ersatzbank oder so"
#                     ]
#                 },
#                 {
#                     "player_name": "Niklas Süle",
#                     "comments": [
#                         "@niklaxs_09",
#                         "🖤💛 🍀",
#                         "⚡ 🇧🇷🖤💛",
#                         "🖤💛 🫶",
#                         "ن",
#                         "Klas 🌠💎",
#                         "Happy Birthday 💛🖤💛 lieber Niklas Süle 🖤💛🖤"
#                     ]
#                 },
#                 {
#                     "player_name": "Julian Brandt",
#                     "comments": [
#                         "@julian_svk_",
#                         "Julian🥹🥹",
#                         "ن",
#                         "Where is Julian Brandt"
#                     ]
#                 },
#                 {
#                     "player_name": "Karim Adeyemi",
#                     "comments": [
#                         "Adeyemi?",
#                         "Warum adeyemi",
#                         "Adeyemi 🔥🔥🔥🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Serhou Guirassy",
#                     "comments": [
#                         "Being unserem glück verletzt sich guirassy...😢",
#                         "I'm so happy to see guirassy",
#                         "Serhou Guirassy Guirassy, Serhou Guirassy 🖤💛",
#                         "Guirassy 🔥🔥🔥",
#                         "Guirassy 🔥🖤💛"
#                     ]
#                 },
#                 {
#                     "player_name": "Nico Schlotterbeck",
#                     "comments": [
#                         "Emre can wie kann so einer Kapitän sein der schlechteste Mittelfeld spieler in der BL ein sabitzer sitzt 75 Minuten auf der bank schlotterbeck grauenhaft couto auch echt nicht gut dieses spiel dann kommt ein bensebaini rein der absolut schlecht ist schon seit dem er bei Dortmund ist beier auch echt nicht gut also und das schlimmste ist keiner außer ryerson und guirassy hat versucht zu kämpfen",
#                         "🖤💛 🍀",
#                         "⚡ 🇧🇷🖤💛",
#                         "🖤💛 🫶",
#                         "Ich bin kein ausgebildeter Fussballlehrer , würde mir gern wünschen mehr offensive , Kobel - Bensebaini - Schlotterbeck - Süle - Ryerson/Couto - Gittens - Brandt - Can - Duranville/Malen - Adeyemi/Beier als HS/MS - Guirassy ...why Not ??? 😉⚽⚽🤔.. Bitte 3 Punkte morgen.👏",
#                         "ن",
#                         "My favourite player is always famous @gregorkobel @nico.schlotterbeck",
#                         "@nico.schlotterbeck 😍💛🖤💛🖤😍",
#                         "Neuer Stürmer @nico.schlotterbeck",
#                         "Schlotterbeck",
#                         "Nico 🤨",
#                         "@nico.schlotterbeck Handzeichen von nurisahin oder von @its_lazzo_time gelernt 😂"
#                     ]
#                 },
#                 {
#                     "player_name": "Gregor Kobel",
#                     "comments": [
#                         "🖤💛 🍀",
#                         "⚡ 🇧🇷🖤💛",
#                         "🖤💛 🫶",
#                         "Kobel",
#                         "My favourite player is always famous @gregorkobel @nico.schlotterbeck",
#                         "@gregorkobel, Wahnsinn deine Leistung 😍",
#                         "Kobel😢",
#                         "Kobel🫶🏼🔥❤️",
#                         "Kobel 🇨🇭"
#                     ]
#                 },
#                 {
#                     "player_name": "Waldemar Anton",
#                     "comments": [
#                         "🖤💛 🍀",
#                         "⚡ 🇧🇷🖤💛",
#                         "🖤💛 🫶",
#                         "ن"
#                     ]
#                 },
#                 {
#                     "player_name": "Maximilian Beier",
#                     "comments": [
#                         "Wer?"
#                     ]
#                 }
#             ]
#         },
#         {
#             "club_name": "fcbayern",
#             "players": [
#                 {
#                     "player_name": "Min-Jae Kim",
#                     "comments": [
#                         "k❤️",
#                         "Minjae!",
#                         "민재😍",
#                         "@iwhead 김민재 뭐냐 자주나오네 ㅋㅋ",
#                         "민재 어색😂",
#                         "민재야 뮌헨에서 행복해야해",
#                         "Anjir minjae 🔥",
#                         "킴민재!🔥🔥",
#                         "minjae zzzzz🙌🔥🔥",
#                         "Minjae 👍🏃‍♂️🏃‍♂️🏃‍♂️🏃‍♂️🏃‍♂️🏃‍♂️🏃‍♂️❤️❤️❤️❤️❤️",
#                         "민재 귀여워🥹",
#                         "김민재 귀여워❤️",
#                         "민재 왜 어색해하는데ㅋㅋㅋ",
#                         "민재 선수 자주 보여서 좋고만 ㅎ",
#                         "😂 ❤️",
#                         "Minjae!!",
#                         "머지?? 민재님 핑크가 찰떡~",
#                         "minjae🔥🔥🔥😂",
#                         "민재👏👏👏",
#                         "Minjae ❤️🏃‍♂️🏃‍♂️🏃‍♂️🏃‍♂️🏃‍♂️🏃‍♂️👍",
#                         "Minjae 🔥🔥🔥",
#                         "Minjae 🔥🔥🔥🔥",
#                         "민재🤭🤭🤭",
#                         "minjae🔥🔥😊😊",
#                         "민재❤️",
#                         "민재 표정ㅋㅋ",
#                         "We need the picture from minjae with the paper beer",
#                         "He is better than minjae right now",
#                         "Hab gehört kompany wechselt sich selbst ein falls es mal mit upa oder minjae nicht läuft😂",
#                         "🥶 🔥",
#                         "Minjae?",
#                         "김민재❤️😂",
#                         "민재 괴물수비!🔥🔥",
#                         "Minjae😂😍😍",
#                         "민재얍🫶🏻🫶🏻🫶🏻",
#                         "❤️❤️ 🤍🤍",
#                         "🍺🥨　🔥",
#                         "Pls Kompany start over min jae Kim next game 🙏",
#                         "👏👏👏 🔥❤️",
#                         "Minjae 👍😊😍😘👏💗💗💗💗💗",
#                         "Minjae 🍺👏❤️",
#                         "김민재 귀여워",
#                         "❤️❤️❤️❤️👏 👏👏🔥🔥🔥",
#                         "🍻 ❤️👆🏼🐶"
#                     ]
#                 },
#                 {
#                     "player_name": "Joshua Kimmich",
#                     "comments": [
#                         "k❤️",
#                         "Kimmich 🤨❤️",
#                         "Kimmich 😂",
#                         "😂 ❤️",
#                         "🥶 🔥",
#                         "❤️❤️ 🤍🤍",
#                         "🍺🥨　🔥",
#                         "👏👏👏 🔥❤️",
#                         "❤️❤️❤️❤️👏 👏👏🔥🔥🔥",
#                         "🍻 ❤️👆🏼🐶"
#                     ]
#                 },
#                 {
#                     "player_name": "Aleksandar Pavlovic",
#                     "comments": [
#                         "k❤️",
#                         "Volvic☝🏼",
#                         "@alekspavlovic_ du hast aber Gas gegeben 😂👍",
#                         "min jae and pavlovic😍",
#                         "😂😂😂 aleks❤️❤️❤️",
#                         "min jae and pavlovic ❤️"
#                     ]
#                 },
#                 {
#                     "player_name": "Alphonso Davies",
#                     "comments": [
#                         "What a man, what a player Alphonso Davies 😂",
#                         "😂 ❤️",
#                         "Davies😎😎",
#                         "🥶 🔥",
#                         "❤️❤️ 🤍🤍",
#                         "🍺🥨　🔥",
#                         "👏👏👏 🔥❤️",
#                         "❤️❤️❤️❤️👏 👏👏🔥🔥🔥",
#                         "🍻 ❤️👆🏼🐶"
#                     ]
#                 },
#                 {
#                     "player_name": "Michael Olise",
#                     "comments": [
#                         "Olise🔥",
#                         "Michael o. 👏🔥",
#                         "Michael Coldise 🥶",
#                         "@m.olise 🔥",
#                         "Olise😎",
#                         "Just 🪄 feeling 👏👏 Michael #Olise @fcbayern ❤️🤍 #packmas",
#                         "Michael Olise aura 1000 🤫👈",
#                         "@m.olise 😂😂🔥",
#                         "Olise😂😂😂🔥",
#                         "Olise 😎🍺",
#                         "Olise: 🗿🍺",
#                         "Olise 😂❤️",
#                         "Olisee😎😎😎",
#                         "Olise❤️😂",
#                         "Michael Olise te amo 🤫👈",
#                         "olise🥶",
#                         "olise👏",
#                         "olise 😍🔥",
#                         "Olise 😎",
#                         "Olise 🥶",
#                         "Olise😂🔥",
#                         "Lil olise 🔥",
#                         "Tel 🪄olise🔥",
#                         "Michael + olise❤️‍🔥🔥",
#                         "Olise😭😭😭😭",
#                         "Olise 🔥🔥🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Serge Gnabry",
#                     "comments": [
#                         "ნა",
#                         "Gol de gnabry😍",
#                         "Serge Gnabry?"
#                     ]
#                 },
#                 {
#                     "player_name": "Jamal Musiala",
#                     "comments": [
#                         "Musiala 🔥🔥❤️",
#                         "Jamal 😍❤️",
#                         "jamal musialaa🔥",
#                         "Jmal ❤️",
#                         "Congratulations to our great players Harry Kane and Jamal Musiala❤️",
#                         "Herzlichen Gluckwunsch zu @harrykane and @jamalmusiala10 Super Jungs habt es verdient 👏👏👏👏💪🏼💪🏼💪🏼💪🏼❤️❤️❤️❤️",
#                         "Congrats 🎊🍾🎉 broski @jamalmusiala10 and @harrykane",
#                         "Congrats Harry Kane and Jamal musiala ❤️🎉",
#                         "Jamal ❤️",
#                         "Jamal musiala is not muslim I think 🤔",
#                         "@jamalmusiala10 😏😏",
#                         "1v1 musiala😂😂😂",
#                         "Jamal Musiala X Olise 🔥",
#                         "Musiala???",
#                         "@jamalmusiala10  you’re not 18+ 😂",
#                         "Is @jamalmusiala10 old enough to drink 🍺 👀 only asking for a friend",
#                         "Jamal❤️🔥",
#                         "Musiala...... 💔😔"
#                     ]
#                 },
#                 {
#                     "player_name": "Manuel Neuer",
#                     "comments": [
#                         "Neuer🔥",
#                         "Manuel Neuer bester Torwart aller Teiten🍻🔥",
#                         "Manuel Neuer wieder zum DFB Danke",
#                         "Neuer❤️❤️❤️❤️❤️",
#                         "PROST LIEBE @manuelneuer 🍻🍺🍻🍺",
#                         "😂 ❤️",
#                         "🥶 🔥",
#                         "❤️❤️ 🤍🤍",
#                         "🍺🥨　🔥",
#                         "👏👏👏 🔥❤️",
#                         "neuer?🍻🍺",
#                         "❤️❤️❤️❤️👏 👏👏🔥🔥🔥",
#                         "🍻 ❤️👆🏼🐶"
#                     ]
#                 },
#                 {
#                     "player_name": "Leroy Sane",
#                     "comments": [
#                         "Leroy sane👏👏👏👏🔥",
#                         "@fler",
#                         "Kane❤️❤️❤️❤️👏"
#                     ]
#                 },
#                 {
#                     "player_name": "Dayot Upamecano",
#                     "comments": [
#                         "😂 ❤️",
#                         "Mejor que upamecano",
#                         "Better than upamecano",
#                         "Play him instead of upamecano 🙏🗣️",
#                         "Kompany ya retirado es mejor que kim y upamecano",
#                         "Mil veces mejor así retirado que upamecano",
#                         "Better than upamecano😂",
#                         "🥶 🔥",
#                         "já dá p jogar no lugar do upamecano",
#                         "Kompany still better than Kim and upamecano😳",
#                         "ت🙌🙌",
#                         "❤️❤️ 🤍🤍",
#                         "🍺🥨　🔥",
#                         "👏👏👏 🔥❤️",
#                         "❤️❤️❤️❤️👏 👏👏🔥🔥🔥",
#                         "🍻 ❤️👆🏼🐶"
#                     ]
#                 }
#             ]
#         },
#         {
#             "club_name": "fcchelsea",
#             "players": [
#                 {
#                     "player_name": "Ben Chilwell",
#                     "comments": [
#                         "can we let chilwell play next game please 🙏",
#                         "I still like chillwel",
#                         "No doubt about it, I prefer him over chilwell atm",
#                         "Making us to forget about chilwell 👏",
#                         "Well"
#                     ]
#                 },
#                 {
#                     "player_name": "Joao Felix",
#                     "comments": [
#                         "Joao felix and nkunku time 🔥🔥",
#                         "If Joao Felix He Send It Directly Volleyball 😑.",
#                         "let’s not forget that Joao Felix also had a hell of a free kick also this past week."
#                     ]
#                 },
#                 {
#                     "player_name": "Cole Palmer",
#                     "comments": [
#                         "No palmer🙂‍↕️",
#                         "No palmer... WHYYYY😢",
#                         "Palmer 💙",
#                         "Mr cord palmer🙌🙌 again 💙",
#                         "Congratulations Cole Palmer, do it again, again, again, again ❄️❄️❄️",
#                         "Cold palmer 🙌🏾🙌🏾",
#                         "Next goat cole palmer 🔥",
#                         "Palmer🔥",
#                         "It’s the way Cole Palmer drifted into midfield position from an attacking position to make this sublime pass for me.. if you watched the earlier build up play. His football IQ is on 💯✅🫡",
#                         "Cool palmer🥶",
#                         "Thank you Cole Palmer for restoring  the pride of London! 🥶💙👏🏿I am beginning to recognise my Club again!!!",
#                         "Lionel palmer???. 😂 are u ok?? Stupid question..",
#                         "🥶 palmer 😍😍😍😍😍💙💙💙",
#                         "Gold palmer",
#                         "Best player in the world after Messi 😍🥶. @colepalmer10",
#                         "🥶🥶🥶 cold palmer my favorite player in the premier league  vamos Chelsea palmer the best in the league better than phil poden",
#                         "@colepalmer10 🔥",
#                         "Палмер 🔥🔥🔥",
#                         "Cole ⭐️",
#                         "The next @hazardeden_10 @colepalmer10 😮‍💨",
#                         "Cole Palmer ❌Kul Palmer ✅",
#                         "Palmer 🥶🗿",
#                         "Cole palmer.. The next EH 10",
#                         "vcs não merecem o palmer",
#                         "🥶🥶🥶🥶🥶coldpalmer",
#                         "Brilliant cole palmer 🥶💙💙",
#                         "@colepalmer10  Thank you for choosing Chelsea 😭👏💙",
#                         "Palmer 💙❤️🔥",
#                         "Palmer 😢😢😢🔥🔥🔥🔥🔥",
#                         "NJ is a fantastic footballer. His runs and movements is awesome. Cole palmer legend",
#                         "Who else can do that @colepalmer10",
#                         "damn cole palmer would be winning the best player award if not for people pulling him down",
#                         "Palmer",
#                         "Palmer 🤔🥶",
#                         "Waiting cold palmer POTW efootball 103🥶",
#                         "The best @colepalmer10",
#                         "This Boy Cole Palmer is so cool 🥶🔥",
#                         "Cole Palmer - a delight to watch!!💙💙💙",
#                         "am I the only one smiling 😊 🤩while looking at this pass from Cole Palmer 🫣💙💙💙",
#                         "@colepalmer10 Soon he will be the best player in the world🔥",
#                         "Mancity academy player Cole Palmer",
#                         "Cole Palmer our joy giver🤩💙Jackson never disappoints btw🥹",
#                         "Nicolas⚽️⚽️palmer",
#                         "Chelsea football club does not deserve Cole Palmer😢",
#                         "Palmer 🥶",
#                         "@colepalmer10 🔥🔥🔥",
#                         "Football = Cole Palmer 😂😂😂",
#                         "@jackson.nj11 Don’t worry man, you are going to score a lot of Goals by God’s grace. I can see the right communication between you and @colepalmer10 💙💙",
#                         "@colepalmer10 iconic 👏🔥💙",
#                         "@jackson.nj11 denied @colepalmer10  the best assist of  the decade",
#                         "Palmer 🥶🥶🔥🔥🔥",
#                         "Jackson was just rendering the assist efforts of Cole Palmer useless...Jackson why?",
#                         "If Cole palmer plays with real strikers man will have hundreds assists in one season",
#                         "That’s why we called him cold palmer🥶",
#                         "Cole Palmer has given admin a whole lot of content for the entire week!Man doesn’t need to look into his archives😂😂🤣🤣",
#                         "Does this Cole Palmer even train? Because I hardly see him train with others. All Chelsea legends often don't like training with others, even Eden Hazard. He was feeling reluctant to training but would end up winning the MOTM",
#                         "Honestly I've never seen such pass before Cole Palmer 🥶🥶🥶",
#                         "Cole palmer is like MVP Russell westbrook - love him though",
#                         "Boy Genius! 🧊Cole Palmer.",
#                         "Jesus!!! This guy call @colepalmer10 🔥🔥🔥💙💙💙💙",
#                         "Cole 🥶",
#                         "Dulu kita membuang KDB sekarang dia yang membuang cold palmer🔥",
#                         "Cold palmer innit button",
#                         "Thats our gold palmer🔥🔥",
#                         "That’s why he’s called Cole Palmer innit?",
#                         "Cole Palmer ❌ Lionel Palmer ✅",
#                         "Palmer 🔥",
#                         "simplesmente cold palmer 🥶🥶",
#                         "Cold messi or Lionel palmer 😍",
#                         "Cole Palmer knew his self-worth from a young age. 🔥🔥🔥",
#                         "🥶 😍",
#                         "Cole Palmer ❌ Too easy ✅",
#                         "🔥🔥🔥🔥🙌 @colepalmer10",
#                         "Cole palmer❌cold palmer✅",
#                         "Cole Palmer innit",
#                         "With Cole Palmer all things are possible @colepalmer10",
#                         "Umpan yang brilian dari @colepalmer10 🔥🙌",
#                         "Cold palmer or lionel palmer??",
#                         "Cole palmer fans🔥🔥🙌",
#                         "🔥 ❤️",
#                         "Palmer 😍🥶",
#                         "Chelsea 😐 Cole Palmer 🥶💙😍",
#                         "Palmer🥶🥶🥶",
#                         "Cole Palmer 💙👏🏻",
#                         "🥶palmer",
#                         "He is not a new Pep, Mourinho, Ancelotti, etc. Like OUR Cole Palmer, He is OUR Enzo Maresca! 💙",
#                         "Manager of the month for sure cole Palmer player of the month both people have carried this club 🥶🔥",
#                         "Con todo cole palmer",
#                         "@colepalmer10 💙🥶",
#                         "Manager of the month Player of the month Goal of the month @chelseafc @colepalmer10 @premierleague",
#                         "Maresca - Manager of the Month! Cole Palmer - Player of the Month! 🥶🤝",
#                         "Enzo maresca🥶🥶🥶🥶🥶🥶, Cole palmer🥶🥶🥶🥶🥶🥶🥶🥶",
#                         "Enzo Maresca~ manager of the month ~ Cole Palmer ~ player of the month ~  Cole Palmer free kick or Christopher Nkunku goal against  bournemouth goal of the month and Sanchez penalty save~ Save of the month",
#                         "@colepalmer10 my twin palmer",
#                         "Manager of the month- Enzo Maresca. Player of the month- Cole Palmer.  Goal of the month- Cole Palmer. @colepalmer10",
#                         "Chelsea won 3 and Cole Palmer won 1",
#                         "MANAGER of the month September  Cole palmer  player of the month September",
#                         "Cole Palmer FC",
#                         "cold palmer abis masak burung camar🔥🥶",
#                         "Cole Palmer FC?",
#                         "Missed 4 easy goals vs crystal palace , palmer sat down that game being sad about it,  after that he took it personally 🤣 ! It would have been like seven heaven if we would have won against palace but nevertheless we keep up the momentum going 💙 up the chels 💙💪🏻",
#                         "Cole Palmer is rebuilding this great club!",
#                         "💙💙💙💙💙 🔥🔥",
#                         "All credit to our wonder kid @colepalmer10 🥶🥶",
#                         "Manager of the month for enzo maresca and player of the month for Cole Palmer no doubt 🔥",
#                         "@marcosalonso28 💙 @colepalmer10 🥶",
#                         "@colepalmer10 💙💙💙",
#                         "September : Enzo Maresca coach of the month, Cole Palmer : player of the month, Cole Palmer : Goal of the month 🙌🔥",
#                         "Palmer💙💙",
#                         "Al fin paso de palmer penaltis a palmer realmente buen jugador 👏🏻",
#                         "Palmer🥶",
#                         "I wish England will hire southgate and fire him again for not starting Cole Palmer in 7 straight matches in euros",
#                         "When cole palmer Scored that freekick goal the first person that came into my mind was Marcos Alonso",
#                         "@marcosalonso28 @colepalmer10",
#                         "Willian to alonso , alonso to palmer",
#                         "🥶🥶🥶 Ice palmer @colepalmer10",
#                         "Cole 🔥🔥🔥",
#                         "@colepalmer10 my love 😍😍 😍 keep the good work going soon you be world number one",
#                         "Alonso itu alonso.. hazard itu hazard.. drogba itu drogba.. lampard itu lampard. Costa itu costa.. dan biarkan palmer jadi cold palmer 💙🥶",
#                         "@marcosalonso28 @colepalmer10 🥶🥶🔵🟦💙💙💙",
#                         "Cole Palmer own is way far than Alonso what a player 😂",
#                         "@colepalmer10 is the best👏",
#                         "cold ALONSO Palmer 😂 💙 @colepalmer10 @marcosalonso28",
#                         "Phenomenal Cole Palmer 🔥🔥",
#                         "@marcosalonso28 🔥🔥 @colepalmer10 🔥🔥💙💙",
#                         "Palmer ¤🔥",
#                         "Wait I recognize that goal ......@marcosalonso28 scored this goal before 🥶@colepalmer10 is a true blue🥶💙💙",
#                         "Cole Palmer",
#                         "@marcosalonso28 🔥🔥@colepalmer10",
#                         "That's why they call ice cold palmer innit 🥶",
#                         "Iceeeeeee cold Palmer 🥶💙",
#                         "PPalmer",
#                         "Everybody loves Cole Palmer 🥶💙",
#                         "Cold palmer",
#                         "Ice Cole Palmer 🥶🥶💙",
#                         "Cole palmer ko gbo oun pa 😂😂😂😂.....dem don cut off his ears 😂😂....if hin papa be goal keeper ...cold go net am 😂",
#                         "We go from Mason Mount to Cool Palmer",
#                         "God bless the scout behind @colepalmer10 he had been more than a blessing to us 👏 😢any injury that wants to happen to cole Palmer should happen to mount and rashford amen 👏🙌🔥",
#                         "Cole palmer for a reason 💙💙💙🙌🙌💙🔵🔵🔵🔷🔷✨✨✨✨",
#                         "Cole 💙💙💙",
#                         "Ice cold Palmer 🥶🥶🥶🥶🥶🥶🥶💙💙💙💙🙌🙌🙌🙌",
#                         "NOTHING YOU WAN TELL ME @colepalmer10 na ICE 🧊 🥶 alien 👽",
#                         "Never leave us @colepalmer10 ❤️🔥",
#                         "Admin please am a Chelsea fan from Nigeria Iand I want to come and watch Cole Palmer live at Stamford bridge",
#                         "Amazing player Cole Palmer, his presence gives everyone confidence even the fans",
#                         "God bless who scouted cole palmer and confused chelsea to sign him",
#                         "Cole Palmer 🥶🥶🔵😊😊",
#                         "The thing I noticed about Cole Palmer is that he makes the other boys want to play better, he raises the morale, his performances are like a team talk",
#                         "Palmer 🙌",
#                         "10/10 penalties for #CFC. 10/10 performance. @colepalmer10! 💙",
#                         "It’s cole Palmer",
#                         "Pen palmer 🐐",
#                         "Cold palmer, he is him💀💀🔥",
#                         "Who is Cole Palmer? For the blind, he is the vision. For the hungry, he is the chef. For the thirsty, he is the water. If Palmer thinks, I agree. If Palmer speaks, I'm listening. If Palmer has one fan, it is me. If Palmer has no fans, I don't exist 🔵🔵🔵",
#                         "👏 🥶",
#                         "Palmer 🤍⚽️",
#                         "💙 💙💙💙",
#                         "thank you Man City for Cole Palmer!!! Returning the favour we did when Kevin De Bruyne went the other way.",
#                         "👏👏Cole Palmer is the best player in the English league",
#                         "Hi Chelsea fans , do you know that Cole Palmer might end up being the best player to ever play for our club , forget that it's happening in our time .",
#                         "We need win this league to show Cole Palmer to the world",
#                         "All thanks to cole palmer he has putting smiles back on our faces👏❤️",
#                         "City took Kevin De Bruyne and The Blues take Cole Palmer back ☺️",
#                         "congratulations Cole palmer, star player setting records and breaking records that's what Cristiano Ronaldo and Lionel Messi",
# ...
#                         "🔥🔥🔥🔥🔥jawohl du bist unsere Zukunft im Tor @dennisseimen_ wir Fans sind anders stolz darauf dich im Tor zu sehn 😍😍😍",
#                         "Hoffentlich keine Austiegsklausel 🫠 @dennisseimen_ du machst das 🔥",
#                         "Jawoll! 🔥 @dennisseimen_ 🔥",
#                         "Wünsche dir alles gute 💪🏻🍀 @dennisseimen_",
#                         "🤍❤️Dennis Seimen 🤍❤️",
#                         "Dennis seimen",
#                         "😍👌 stark. Wir wünschen Dennis Seimen eine verletzungsfreie/arme lange erfolgreiche Karriere beim VfB  Euer FVU 🔵⚽️🔥",
#                         "🔥 🇷🇴",
#                         "🇮🇶 🔥❤️",
#                         "️💫mean",
#                         "Amen🙏",
#                         "🇮🇶 🙌❤️",
#                         "🇮🇶 🙌🔥",
#                         "🔥🇺🇸 🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Fabian Bredlow",
#                     "comments": [
#                         "🤍❤️ 🔥",
#                         "🙌🙌🚀💣💥 🤍❤️",
#                         "👏🏽 ⚪🔴",
#                         "❤️‍🔥 ⚪️🔴",
#                         "❤️☀️💚 ✌️",
#                         "🇩🇪 💚❤️💛🇩🇪",
#                         "🤍❤️ 💪🏻💪🏻",
#                         "🔥🤍❤️😍 🍀",
#                         "🤍❤️ 🔥🔥",
#                         "🤍 ❤️🤍❤️🤍❤️🤍❤️",
#                         "fabian rieder masterclass",
#                         "🔥 🇷🇴",
#                         "Wow🔥🔥🔥😈😍",
#                         "Wow😍",
#                         "🇮🇶 🔥❤️",
#                         "wow👍🏻",
#                         "🇮🇶 🙌❤️",
#                         "🇮🇶 🙌🔥",
#                         "🔥🇺🇸 🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Stefan Drljaca",
#                     "comments": [
#                         "🤍❤️ 🔥",
#                         "🙌🙌🚀💣💥 🤍❤️",
#                         "👏🏽 ⚪🔴",
#                         "❤️‍🔥 ⚪️🔴",
#                         "❤️☀️💚 ✌️",
#                         "🇩🇪 💚❤️💛🇩🇪",
#                         "🤍❤️ 💪🏻💪🏻",
#                         "🔥🤍❤️😍 🍀",
#                         "🤍❤️ 🔥🔥",
#                         "🤍 ❤️🤍❤️🤍❤️🤍❤️",
#                         "🔥 🇷🇴",
#                         "🇮🇶 🔥❤️",
#                         "🇮🇶 🙌❤️",
#                         "🇮🇶 🙌🔥",
#                         "🔥🇺🇸 🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Ameen Al-Dakhil",
#                     "comments": [
#                         "🤍❤️ 🔥",
#                         "🙌🙌🚀💣💥 🤍❤️",
#                         "👏🏽 ⚪🔴",
#                         "❤️‍🔥 ⚪️🔴",
#                         "❤️☀️💚 ✌️",
#                         "🇩🇪 💚❤️💛🇩🇪",
#                         "🤍❤️ 💪🏻💪🏻",
#                         "🔥🤍❤️😍 🍀",
#                         "Where is @ameen_aldakhil",
#                         "🤍❤️ 🔥🔥",
#                         "🤍 ❤️🤍❤️🤍❤️🤍❤️",
#                         "🔥 🇷🇴",
#                         "ameen",
#                         "@ameen_aldakhil  البطل 🦁",
#                         "Ameen🤩",
#                         "Ameen aldkhil 🔥",
#                         "Ameen🔥🔥🇮🇶",
#                         "@ameen_aldakhil 🇮🇶🔥🔥🔥😉",
#                         "Ameen🔥🔥🇮🇶🇮🇶🇮🇶😘",
#                         "@ameen_aldakhil Good bro 🙌👏❤️",
#                         "🇮🇶 🔥❤️",
#                         "Herzlich willkommen in der Bundesliga @ameen_aldakhil",
#                         "اكو بلجيكي معلق الك  ومساندك وداعمك بكد العراقين @ameen_aldakhil",
#                         "Welcome @ameen_aldakhil",
#                         "نحتاجك في المنتخب العراقي🇮🇶 يا @ameen_aldakhil ❤️",
#                         "Erstens bin ich als Stuttgart-Fan stolz, und zweitens bin ich stolz darauf, dass Du aus der gleichen Herkunft wie ich stammen und für den Verein spielen werden, den ich sehr liebe ,Du hast die beste Entscheidung deines Lebens getroffen, Stuttgart und die Fans hier sind die besten der Welt@ameen_aldakhil 🤍❤️",
#                         "All the Best for the New season!! Lets go @ameen_aldakhil ❤️🤍",
#                         "@ameen_aldakhil  اسدنا٠❤️‍🔥🇮🇶😭",
#                         "Welcome @ameen_aldakhil 🔥🙌",
#                         "🤍 @ameen_aldakhil",
#                         "Amen 🙌",
#                         "@ameen_aldakhil ❤️🦁🇮🇶البلد بحاجتك ارجع محد يوكفلك ويوكف وياك غير ابناء بلدك ننتظر منك اخبار مفرحه وجديده كدامنه تصفيات المنتخب يعاني من قلوب الدفاع انته راح تملي الفراغ ومعليك بكم شخص يعلق تعليق سلبي من حبه الك جان يريد يشوفك بلمنتخب لكن قدر الله ما شاء فعل والفرصه اعتقد موجوده بعدها اتمنى ترد على تعليقي حتى نعرف انو اكو امل بلموضوع",
#                         "So proud of you 🇮🇶⏳@ameen_aldakhil 👏🏻",
#                         "🇮🇶 🙌❤️",
#                         "@ameen_aldakhil Our pride, we wish you the best 🇮🇶",
#                         "Good luck for the best @ameen_aldakhil",
#                         "🇮🇶 🙌🔥",
#                         "Good luck @ameen_aldakhil 🇮🇶🐐",
#                         "@ameen_aldakhil We trust you and you will represent our national team, the national team of your mother country. Do it for your people, Amin. We are waiting for you in Basra and Baghdad.",
#                         "Good luck @ameen_aldakhil 🫶🇮🇶❤️",
#                         "🔥🇺🇸 🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Ermedin Demirovic",
#                     "comments": [
#                         "demirovic 🇧🇦",
#                         "Warum kein demirovic?",
#                         "Demirovic⚜️⚜️⚜️⚜️",
#                         "👏👏👏💪💪demirovic go",
#                         "Wir haben keine Angst vor Real Madrid  Weil wir zwei Stürmer haben, einer ist #DenizUndav und der andere ist #ErmedinDemirovic. #Vfb",
#                         "Demirovic 👏",
#                         "Demirovic 🔥",
#                         "Demirović 🇧🇦🇧🇦🇧🇦‼️‼️‼️🐐🐐🐐",
#                         "Wer ist ist Guirassy? Ermedin Demirovic erledigt nun das Toreschießen! Weiter so.",
#                         "Nein 😭😭😭",
#                         "Ermedin Demirović 🇧🇦‼️"
#                     ]
#                 },
#                 {
#                     "player_name": "Fabian Rieder",
#                     "comments": [
#                         "Wieso nie @fabianrieder32 von Beginn?",
#                         "Rieder🦁",
#                         "Ich bin Fabian Rieder Fan seit der EM und VfB Fan seit Hansi Müller😂... So happy, dass er bei uns spielt😍",
#                         "Fabian Rieder Masterclass",
#                         "@fabianrieder32 great work from the Reider’s (Rieder) from the USA!!",
#                         "So stolz auf Euch 😍🔥 @cjfuehrich @fabianrieder32 @fbredlow @e.demirovic29 @jamieleweling",
#                         "Rieder ❤️🇨🇭",
#                         "Rieder❤️❤️❤️",
#                         "Fabian Rieder ist brutal 🔥",
#                         "@fabianrieder32 🔝👍👏",
#                         "Fabian Rieder goat❤️",
#                         "Rieder 🔥",
#                         "fabian rieder masterclass",
#                         "ich hoffe @fabianrieder32 macht wieder ein Freistosstor",
#                         "Leider",
#                         "Ein Punkt gegen den Abstiegskampf, weiter so! @fabianrieder32 …. deine Freistösse werden uns noch weiterhin erfreuen, grandios!",
#                         "JUGADORES MEDIOCRES DE TERCERA CATEGORÍA DEBERÍAN LARGARSE COMO @fabianrieder32",
#                         "Rieder🥶🥶🥶",
#                         "Ich hoffe das Fabian Rieder Heute spielen wird",
#                         "Fabian Rieder sieht so aus wie ich, wenn mir bewusst wird, dass morgen mein letzter Arbeitstag vor 3 Wochen Urlaub ansteht😂"
#                     ]
#                 },
#                 {
#                     "player_name": "Angelo Stiller",
#                     "comments": [
#                         "Mega spiel vom @vfb Kopf hoch @atakrzr @cjfuehrich @jamieleweling @e.millot17 @angelo.stiller @e.demirovic29",
#                         "Ihr schämt euch verdammt nochmal für garnix! Ihr habt euer Herz und alles auf dem Platz gelassen! Ihr habt alles gegen! Und auch wenn die Spieler verständlicherweise enttäuscht sind, rafft euch auf und gewinnt die kommenden Spiele! Ihr habt gezeigt was ihr drauf habt und belohnt euch alle für das was ihr auf dem Platz lasst! Ihr habt jeden VFB‘ler mit stolz erfüllt und mit dieser Kraft geht ihr in die nächste Aufgabe!!!!!!!! FORZA VFB @jamieleweling @atakrzr @angelo.stiller @maximittelstaedt",
#                         "🤑thriller",
#                         "@angelo.stiller verdient🤞🏽❤️",
#                         "geil 🤩",
#                         "Baller",
#                         "Banger",
#                         "@angelo.stiller MOTM? @atakrzr Tor war deutlich schwerer 😳 GOAT",
#                         "@angelo.stiller eines Tages bekomme ich ein Trikot von dir",
#                         "@angelo.stiller 🔥😍❤️",
#                         "Angelo Stiller ist so krass NIE WIEDER IV da ist der ein wasted talent( karazor spielt in letzter zeit viele fehlpässe)❤️❤️"
#                     ]
#                 },
#                 {
#                     "player_name": "Jamie Leweling",
#                     "comments": [
#                         "Mega spiel vom @vfb Kopf hoch @atakrzr @cjfuehrich @jamieleweling @e.millot17 @angelo.stiller @e.demirovic29",
#                         "Ihr schämt euch verdammt nochmal für garnix! Ihr habt euer Herz und alles auf dem Platz gelassen! Ihr habt alles gegen! Und auch wenn die Spieler verständlicherweise enttäuscht sind, rafft euch auf und gewinnt die kommenden Spiele! Ihr habt gezeigt was ihr drauf habt und belohnt euch alle für das was ihr auf dem Platz lasst! Ihr habt jeden VFB‘ler mit stolz erfüllt und mit dieser Kraft geht ihr in die nächste Aufgabe!!!!!!!! FORZA VFB @jamieleweling @atakrzr @angelo.stiller @maximittelstaedt",
#                         "@jamieleweling schießt real ab",
#                         "So stolz auf Euch 😍🔥 @cjfuehrich @fabianrieder32 @fbredlow @e.demirovic29 @jamieleweling",
#                         "king🔥😮",
#                         "King🔥",
#                         "Geil wie @jamieleweling am Ende dem Ball ausweicht"
#                     ]
#                 },
#                 {
#                     "player_name": "El Bilal Toure",
#                     "comments": [
#                         "el bilal 😍",
#                         "Wo toure?😭",
#                         "🤙🏽😉 EL bilal touré"
#                     ]
#                 },
#                 {
#                     "player_name": "Anthony Rouault",
#                     "comments": [
#                         "Kann bitte mal jemandem den Kommentatoren sagen, wie man Anthony Rouault ausspricht?🙈 also ein \"j\" sehe ich da nirgends"
#                     ]
#                 },
#                 {
#                     "player_name": "Pascal Stenzel",
#                     "comments": [
#                         "🐐🐐🐐Pascal Stenzel",
#                         "Pascal stenzel",
#                         "Pascal Stenzeo Fusballgott"
#                     ]
#                 },
#                 {
#                     "player_name": "Jeff Chabot",
#                     "comments": [
#                         "Viel Glück aus Köln🔴⚪️ @jeff_le_chabot",
#                         "Chef Chabot...",
#                         "@jeff_le_chabot Sau geiler Typ. Trotz des Väterlichen Geburtstags Autogramme geschrieben und Fotos gemacht. Riesen Respekt 👍💪",
#                         "Wie wär’s damit, wenn nennen Jeff Chabot abjetzt Chef Chabot.",
#                         "Bitte aber ohne chabot"
#                     ]
#                 },
#                 {
#                     "player_name": "Ramon Hendriks",
#                     "comments": [
#                         "Where is Ramón hendriks"
#                     ]
#                 },
#                 {
#                     "player_name": "Frans Krätzig",
#                     "comments": [
#                         "Let's gooooo..... @franskraetzig03 🔥",
#                         "Freue mich auf den besten Spieler auf dem Platz ❤️❤️@franskraetzig03",
#                         "Eigentlich wollte ich nur Autogramme  für mein Kind. Bei Nick Woltemade und Frans Krätzig habe ich dann nach einem für mich gefragt.  So cool und vielversprechend die zwei, ich freue mich wirklich,  dass sie jetzt beim VfB spielen. 🔥🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Nikolas Nartey",
#                     "comments": [
#                         "Hola 👋🏻🤍❤️",
#                         "Nikolas nartey"
#                     ]
#                 },
#                 {
#                     "player_name": "Leonidas Stergiou",
#                     "comments": [
#                         "schön das auch @leonidas.stergiou mit dabei ist 👏"
#                     ]
#                 },
#                 {
#                     "player_name": "Anrie Chase",
#                     "comments": [
#                         "Chase>>",
#                         "chase 💩",
#                         "Anrie Chase👏",
#                         "Anrie Chase Masterclass 👏🏾🤍❤️",
#                         "Absolutes 10/10 spiel von anrie chase",
#                         "Anrie Chase ist der beste Verteidiger jemals💯 was ein Potential der Typ hat",
#                         "Chase>🐍",
#                         "Anrie Chase - absoluter Lichtblick 👏",
#                         "@anrieschase hat mega gut gespielt, einen guten Überblick und hatte gute Impulse was den Spielaufbau angeht. Weiter so 👍🏽. 🤍❤️",
#                         "Nächstes mal ihm die Chance geben 🙏🏼 Hat mir gut gefallen 💪🏼 Glückwunsch zum Debüt, @anrieschase ⚪️🔴",
#                         "Glückwunsch zum debüt @anrieschase"
#                     ]
#                 },
#                 {
#                     "player_name": "Chris Führich",
#                     "comments": [
#                         "Leweling ist der einzige mit Power und Wucht vorne Spielt immer über ihn…was hat er mit Scally und Honorrat gemacht . Der Sprint am Ende und die Vorlage auf Chris Führich🤯 der ist der meist unterschätzte Spieler im Team vom VfB."
#                     ]
#                 },
#                 {
#                     "player_name": "Atakan Karazor",
#                     "comments": [
#                         "Atakan Karazor ❤️🤍🇹🇷"
#                     ]
#                 },
#                 {
#                     "player_name": "Yannik Keitel",
#                     "comments": [
#                         "Yannik keitel"
#                     ]
#                 },
#                 {
#                     "player_name": "Luca Raimund",
#                     "comments": [
#                         "Luca raimund"
#                     ]
#                 },
#                 {
#                     "player_name": "Maximilian Mittelstädt",
#                     "comments": [
#                         "@maximarie_"
#                     ]
#                 },
#                 {
#                     "player_name": "Justin Diehl",
#                     "comments": [
#                         "Wo ist denn Justin Diehl heute?",
#                         "Warum spielt Justin diehl und silas nicht"
#                     ]
#                 },
#                 {
#                     "player_name": "Dan-Axel Zagadou",
#                     "comments": [
#                         "Zagadou🥲"
#                     ]
#                 },
#                 {
#                     "player_name": "Nick Woltemade",
#                     "comments": [
#                         "@nickwoltemade the goat",
#                         "Woltemade 1:2",
#                         "Eigentlich wollte ich nur Autogramme  für mein Kind. Bei Nick Woltemade und Frans Krätzig habe ich dann nach einem für mich gefragt.  So cool und vielversprechend die zwei, ich freue mich wirklich,  dass sie jetzt beim VfB spielen. 🔥🔥"
#                     ]
#                 },
#                 {
#                     "player_name": "Josha Vagnoman",
#                     "comments": [
#                         "️💫mean"
#                     ]
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# # NER

# %%
import spacy

# Laden des mehrsprachigen Modells
nlp = spacy.load('xx_ent_wiki_sm')  # Einfaches mehrsprachiges Modell

def extract_person_entities(text):
    doc = nlp(text)
    return [ent.text.lower() for ent in doc.ents if ent.label_ == 'PER']

example = "cole palmer, there is nothing he can not do face with tears of joy blue heart"

# %%
# Filtere die Zeilen, bei denen die caption das Keyword enthält
keywords = ['Cole Palmer']
'''
filtered_df = df[
    (df['verein'] == 'vfb') &
    (df['caption'].str.contains('|'.join(keywords), case=False, na=False) |
    df['comment'].str.contains('|'.join(keywords), case=False, na=False))
    ]
'''
filtered_df = preprocessed_df[
    (preprocessed_df['verein'] == 'fcchelsea') &
    preprocessed_df['comment_cleaned'].str.contains('|'.join(keywords), case=False, na=False)
    ]

filtered_df

# Extrahiere die Kommentare als Liste
comments_list = filtered_df['comment_cleaned'].tolist()

comments_list
# Out:
# ['congratulations cole palmer, do it again, again, again, again snowflake snowflake snowflake',
#  'it’s the way cole palmer drifted into midfield position from an attacking position to make this sublime pass for me.. if you watched the earlier build up play. his football iq is on hundred points check mark button saluting face',
#  'thank you cole palmer for restoring the pride of london! cold face blue heart clapping hands dark skin tone i am beginning to recognise my club again!!!',
#  'cole palmer.. the next eh 10',
#  'brilliant cole palmer cold face blue heart blue heart',
#  'nj is a fantastic footballer. his runs and movements is awesome. cole palmer legend',
#  'damn cole palmer would be winning the best player award if not for people pulling him down',
#  'this boy cole palmer is so cool cold face fire',
#  'cole palmer - a delight to watch!! blue heart blue heart blue heart',
#  'am i the only one smiling smiling face with smiling eyes star-struck while looking at this pass from cole palmer face with peeking eye blue heart blue heart blue heart',
#  'mancity academy player cole palmer',
#  'cole palmer our joy giver star-struck blue heart jackson never disappoints btw face holding back tears',
#  'chelsea football club does not deserve cole palmer crying face',
#  'jackson was just rendering the assist efforts of cole palmer useless...jackson why?',
#  'if cole palmer plays with real strikers man will have hundreds assists in one season',
#  'cole palmer has given admin a whole lot of content for the entire week!man doesn’t need to look into his archives face with tears of joy face with tears of joy rolling on the floor laughing rolling on the floor laughing',
#  "does this cole palmer even train? because i hardly see him train with others. all chelsea legends often don't like training with others, even eden hazard. he was feeling reluctant to training but would end up winning the motm",
#  "honestly i've never seen such pass before cole palmer cold face cold face cold face",
#  'cole palmer is like mvp russell westbrook - love him though',
#  'that’s why he’s called cole palmer innit?',
#  'cole palmer knew his self-worth from a young age. fire fire fire',
#  'cole palmer cross mark too easy check mark button',
#  'with cole palmer all things are possible',
#  'he is not a new pep, mourinho, ancelotti, etc. like our cole palmer, he is our enzo maresca! blue heart',
#  'manager of the month for sure cole palmer player of the month both people have carried this club cold face fire',
#  'con todo cole palmer',
#  'maresca - manager of the month! cole palmer - player of the month! cold face handshake',
#  'enzo maresca~ manager of the month ~ cole palmer ~ player of the month ~ cole palmer free kick or christopher nkunku goal against bournemouth goal of the month and sanchez penalty save~ save of the month',
#  'manager of the month- enzo maresca. player of the month- cole palmer. goal of the month- cole palmer.',
#  'chelsea won 3 and cole palmer won 1',
#  'manager of the month september cole palmer player of the month september',
#  'cole palmer is rebuilding this great club!',
#  'manager of the month for enzo maresca and player of the month for cole palmer no doubt fire',
#  'september enzo maresca coach of the month, cole palmer player of the month, cole palmer goal of the month raising hands fire',
#  'i wish england will hire southgate and fire him again for not starting cole palmer in 7 straight matches in euros',
#  'when cole palmer scored that freekick goal the first person that came into my mind was marcos alonso',
#  'cole palmer own is way far than alonso what a player face with tears of joy',
#  'everybody loves cole palmer cold face blue heart',
#  'god bless the scout behind he had been more than a blessing to us clapping hands crying face any injury that wants to happen to cole palmer should happen to mount and rashford amen clapping hands raising hands fire',
#  'cole palmer for a reason blue heart blue heart blue heart raising hands raising hands blue heart blue circle blue circle blue circle large blue diamond large blue diamond sparkles sparkles sparkles sparkles',
#  'admin please am a chelsea fan from nigeria iand i want to come and watch cole palmer live at stamford bridge',
#  'amazing player cole palmer, his presence gives everyone confidence even the fans',
#  'god bless who scouted cole palmer and confused chelsea to sign him',
#  'the thing i noticed about cole palmer is that he makes the other boys want to play better, he raises the morale, his performances are like a team talk',
#  'it’s cole palmer',
#  "who is cole palmer? for the blind, he is the vision. for the hungry, he is the chef. for the thirsty, he is the water. if palmer thinks, i agree. if palmer speaks, i'm listening. if palmer has one fan, it is me. if palmer has no fans, i don't exist blue circle blue circle blue circle",
#  'thank you man city for cole palmer!!! returning the favour we did when kevin de bruyne went the other way.',
#  'clapping hands clapping hands cole palmer is the best player in the english league',
#  "hi chelsea fans , do you know that cole palmer might end up being the best player to ever play for our club , forget that it's happening in our time .",
#  'we need win this league to show cole palmer to the world',
#  'all thanks to cole palmer he has putting smiles back on our faces clapping hands red heart',
#  'city took kevin de bruyne and the blues take cole palmer back smiling face',
#  "congratulations cole palmer, star player setting records and breaking records that's what cristiano ronaldo and lionel messi",
#  'cole palmer scored 3 hat-tricks or just two ?one against manchester united and another against brighton , or am i missing something?',
#  'even hazard didn’t even score 3 hattrick and cole palmer did it clapping hands medium-light skin tone such genius player blue heart hundred points',
#  'cole is cole palmer greatest of all time player chelsea fire clapping hands',
#  'thank god for cole palmer red heart snowflake snowflake',
#  'cole palmer already a chelsea legend',
#  'cole palmer will defo create his own class soon',
#  'madrid pls do not come for ice cole palmer pls cold face .',
#  'world best at the moment cole palmer blue heart blue heart blue heart',
#  'sniper fire by cole palmer double exclamation mark sounds like a new aftershave to me. go the blues! clinking beer mugs thumbs up vulcan salute',
#  "a chance for cole palmer, cole palmer scores.. that's how it is all the time. he will conveniently score 5 out of 5 if he isn't unlucky. not jackson who is supposed to be the clinical finisher. they all should learn how to be clinical from cole, but instead they try to beef, especially that bum called madueke. just because he scored 3 he thinks he's arrived and he actually knows next to nothing. palmer scores not because palmer is try to score, he just focuses on his positioning and makes use of the opportunity that comes as best as he could. he also passes when necessary",
#  'cole palmer is everything he thinks he is blue heart',
#  'lucky enough to watch us get that win at the stadium.. cole palmer cold face',
#  'cole palmer finding the net without looking astonished face what a player cold face blue heart',
#  'something happened where we watched the match between chelsea and brighton yesterday. after the first half, a chelsea fan who missed the first half of the match entered the viewing centre to watch the second half of the match was shocked that chelsea are already winning 4-2. when he saw the scoreline, he said “chelsea take am easy na” while walking to a spot to find a space to sit, he asked, “who scored the first goal for chelsea”every shouted “cole palmer” he asked again, the second one everyone shouted again, cole palmer. he asked the third one nko, everyone shouted again, cole palmer (in rhythmic synchrony)he then said okay, the 4th one, everyone again shouted “cole palmer” bro went crazy, pulled his shirt, and started running up and down the viewing centre shouting chelsea!!! chelsea!! chelsea!! (while other fans responded with “for life!!”)the joy and happiness cole palmer brought to chelsea since his signing will remain unmatchable in the history of the club. i bless the day we signed this guy. incredible stuff!',
#  'cole palmer is the debt paid by city for kdb',
#  'ice cold cole palmer, there’s nothing he can not do clapping hands fire',
#  "who is cole palmer cold face cold face ? for the blind face with spiral eyes , he is the vision eyes . for the hungry tired face , he is the chef man cook medium skin tone . for the thirsty upside-down face , he is the water potable water . if palmer thinks thinking face , i agree. if palmer speaks face with open mouth , i'm listening ear with hearing aid medium-dark skin tone . if palmer has one fan, it is me. if palmer has no fans, i don't exist. blue heart blue heart",
#  "please cole palmer deserve's the captain band blue heart",
#  'something happened where we watched the match between chelsea and brighton yesterday. after the first half, a chelsea fan who missed the first half of the match entered the viewing centre to watch the second half of the match was shocked that chelsea are already winning 4-2. when he saw the scoreline, he said “chelsea take am easy na” while walking to a spot to find a space to sit, he asked, “who scored the first goal for chelsea”every shouted “cole palmer” he asked again, the second one everyone shouted again, cole palmer. he asked the third one nko, everyone shouted again, cole palmer (in rhythmic synchrony)he then said okay, the 4th one, everyone again shouted “cole palmer” bro went crazy, pulled his shirt, and started running up and down the viewing centre shouting chelsea!!! chelsea!! chelsea!! (while other fans responded with “for life!!”)the joy and happiness brought to chelsea since his signing will remain unmatchable in the history of the club. i bless the day we signed this guy. incredible stuff!',
#  'god is using cole palmer to put smile in every chelsea fan face and joy in our heart',
#  'cole palmer is a future world best',
#  'cole palmer cold face their is nothing he cannot do',
#  'player of the month cole palmer manager of the month enzo maresca goal of the month cole palmer',
#  'we need peter drury commentary on cole palmer blue heart blue heart blue heart face with tears of joy face with tears of joy face with tears of joy',
#  'ice cold cole palmer fire',
#  'gonna tell my kids i was blessed to watch cole palmer in his prime. cold face cold face cold face cold face cold face cold face cold face cold face cold face cold face blue heart cold face blue heart magnet magnet magnet',
#  "that's why they call him cole palmer innit!",
#  'cole palmer blue heart give him a lifetime contract face with tears of joy blue heart',
#  'cole palmer and sancho’s performance from yesterday’s match was just extraordinary in everything. if maresca use these two players, i believe they will come up with something on the table.',
#  'he a genius cold face . cole palmer is star boy fire',
#  'our very own cole palmer blue heart blue heart blue heart',
#  'cole palmer is hungry',
#  "other chelsea man don't need to justify their price tag because cole palmer is coverig it all up. we will be back to lifting trophies soon when it all comes cool fire clapping hands",
#  'cole palmer is the reincarnation of eden hazard blue heart',
#  'premier league goals this season man utd 5 cole palmer 6 face with tears of joy',
#  '“cole palmer there’s nothing he cannot do” cold face',
#  'told my barista to make my coffee like cole palmer cold face',
#  'our england england team golden boy cole palmer',
#  'for the blind, he is the vision. for the hungry, he is the chef. when he thinks, i agree & when he speaks, i listen. cole palmer, thank you for everything. folded hands medium skin tone loudly crying face',
#  'blue heart blue heart blue heart blue heart cole palmer you are the best.',
#  'blue heart blue heart blue heart cole palmer',
#  'the commentator said “cole palmer there’s nothing he cannot do” clapping hands cold face blue heart',
#  'cole palmer, there is nothing he cannot do',
#  "even cole palmer have free kick goal. still mbappe and haaland doesn't have one hundred points",
#  'it was cole palmer vs sanchez. congrats to our number one player and the history writer cold palmer. the world not going to forget this name forever. clapping hands medium-dark skin tone clapping hands medium-dark skin tone clapping hands medium-dark skin tone clapping hands medium-dark skin tone clapping hands medium-dark skin tone well done chelsea',
#  '“but it is cole palmer over the ball” cold face cold face cold face',
#  'cole palmer to go liverpool urgent! cold face fire',
#  "who is cole palmer? for the blind, he is the vision. for the hungry, he is the chef. for the thirsty, he is the water. if palmer thinks, i agree. if palmer speaks, i'm listening. if palmer has one fan, it is me. if palmer has no fans, i don't exist. blue heart",
#  'cold face cole palmer is cold as ice cold face cold face cold face',
#  "cole palmer player of the month 5 goals in the month of september and cole palmer goal of the month of september i'f anyone else takes it that robbery",
#  'cole palmer, there is nothing he cannot do fire fire absolutely nothing cold face cold face blue heart blue heart blue heart blue heart',
#  'hazard has been reborn in cole palmer blue heart blue heart blue heart blue heart blue heart',
#  'cole palmer there’s nothing he cannot do in football but only god can do all',
#  'cole palmer - "there\'s nothing he cannot do" blue heart blue heart blue heart',
#  'colder then cold that cole palmer cold face cold face',
#  'cole palmer! there’s nothing he can not do clapping hands',
#  'commentator cole palmer! there is nothing he cannot do clapping hands',
#  'cole palmer, there is nothing he can not do face with tears of joy blue heart',
#  '"cole palmer there\'s nothing he can not do"',
#  'cole palmer - there is nothing he cannot do cold face',
#  'cole palmer. there’s nothing he cannot do cold face',
#  'the first record made by young gen z cole palmer deserve more goals in premier league raising hands face with tears of joy blue heart blue heart blue heart blue heart',
#  'great player cole palmer blue heart',
#  'cole palmer you rock my world',
#  'cole palmer the baller red heart',
#  'cole palmer is the way, the truth and the life! blue heart blue heart blue heart',
#  'from mexico bandera méxico te quiero mucho cole palmer cara con frío cara con frío cara con frío',
#  'cole palmer is the best on earth',
#  'eminem, phil foden, cole palmer...they are have conecction']

# %%
for comment in comments_list:
    print(extract_person_entities(comment))
# Out:
# ['congratulations cole palmer']
# ['mark button']
# []
# ['cole palmer']
# ['cole palmer']
# ['cole palmer']
# []
# []
# ['cole palmer - a delight']
# []
# []
# ['cole palmer', 'jackson']
# []
# ['jackson', 'jackson']
# []
# ['cole palmer']
# []
# []
# ['cole palmer', 'russell']
# []
# ['cole palmer']
# ['cole palmer', 'mark button']
# []
# []
# []
# []
# []
# ['enzo maresca~', 'christopher']
# ['enzo maresca']
# []
# []
# ['cole palmer']
# ['enzo maresca']
# ['enzo maresca']
# []
# ['cole palmer']
# ['cole palmer', 'alonso']
# []
# []
# ['cole palmer']
# ['admin']
# []
# []
# []
# []
# ['palmer', 'palmer', 'palmer', 'palmer']
# ['kevin de bruyne']
# []
# []
# []
# []
# ['kevin de bruyne']
# ['congratulations cole palmer', 'cristiano ronaldo', 'lionel messi']
# ['cole palmer']
# ['palmer']
# ['cole']
# []
# ['cole palmer']
# ['cole palmer']
# []
# []
# []
# ['jackson', 'palmer']
# ['cole palmer']
# []
# ['cole palmer']
# ['life!!”)the joy']
# ['cole palmer']
# []
# ['cook', 'skin tone', 'palmer', 'palmer', 'palmer', 'palmer']
# []
# ['life!!”)the joy']
# []
# ['cole palmer']
# ['cole palmer']
# ['enzo maresca']
# ['peter drury']
# []
# ['gonna tell', 'magnet magnet magnet']
# []
# ['cole palmer']
# ['cole palmer', 'sancho']
# ['cole palmer']
# []
# ['cole palmer']
# []
# ['cole palmer']
# []
# []
# []
# []
# ['cole palmer']
# []
# []
# []
# ['cole palmer']
# []
# ['cold palmer']
# []
# ['cole palmer']
# ['palmer', 'palmer', 'palmer', 'palmer']
# []
# ['cole palmer']
# ['cole palmer']
# []
# ['cole palmer']
# ['cole palmer']
# ['colder']
# ['cole palmer']
# ['cole palmer']
# ['cole palmer']
# []
# ['cole palmer - there']
# ['cole palmer']
# []
# []
# ['cole palmer']
# ['cole palmer']
# ['cole palmer']
# []
# ['cole palmer']
# ['eminem', 'phil foden']

# %% [markdown]
# # Sentiment Analysis

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %%
palmer_comments = ["Cole palmer is like MVP Russell westbrook - love him though", "Cole Palmer is a good boy", "Palmer is shit ass", "Palmer is absolutely average"]

# %%
# Loop through the texts and get the sentiment scores for each one
for text in comments_list:
    scores = analyzer.polarity_scores(text)
    print(text)
    print(scores)
# Out:
# congratulations cole palmer, do it again, again, again, again snowflake snowflake snowflake
# {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.5994}
# it’s the way cole palmer drifted into midfield position from an attacking position to make this sublime pass for me.. if you watched the earlier build up play. his football iq is on hundred points check mark button saluting face
# {'neg': 0.069, 'neu': 0.876, 'pos': 0.055, 'compound': -0.1531}
# thank you cole palmer for restoring the pride of london! cold face blue heart clapping hands dark skin tone i am beginning to recognise my club again!!!
# {'neg': 0.0, 'neu': 0.736, 'pos': 0.264, 'compound': 0.8057}
# cole palmer.. the next eh 10
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# brilliant cole palmer cold face blue heart blue heart
# {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.5859}
# nj is a fantastic footballer. his runs and movements is awesome. cole palmer legend
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.8271}
# damn cole palmer would be winning the best player award if not for people pulling him down
# {'neg': 0.101, 'neu': 0.485, 'pos': 0.414, 'compound': 0.8555}
# this boy cole palmer is so cool cold face fire
# {'neg': 0.179, 'neu': 0.597, 'pos': 0.223, 'compound': 0.1509}
# cole palmer - a delight to watch!! blue heart blue heart blue heart
# {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.6688}
# am i the only one smiling smiling face with smiling eyes star-struck while looking at this pass from cole palmer face with peeking eye blue heart blue heart blue heart
# {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.8402}
# mancity academy player cole palmer
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer our joy giver star-struck blue heart jackson never disappoints btw face holding back tears
# {'neg': 0.085, 'neu': 0.539, 'pos': 0.376, 'compound': 0.7568}
# chelsea football club does not deserve cole palmer crying face
# {'neg': 0.256, 'neu': 0.744, 'pos': 0.0, 'compound': -0.4767}
# jackson was just rendering the assist efforts of cole palmer useless...jackson why?
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# if cole palmer plays with real strikers man will have hundreds assists in one season
# {'neg': 0.096, 'neu': 0.783, 'pos': 0.12, 'compound': 0.1027}
# cole palmer has given admin a whole lot of content for the entire week!man doesn’t need to look into his archives face with tears of joy face with tears of joy rolling on the floor laughing rolling on the floor laughing
# {'neg': 0.073, 'neu': 0.653, 'pos': 0.274, 'compound': 0.9098}
# does this cole palmer even train? because i hardly see him train with others. all chelsea legends often don't like training with others, even eden hazard. he was feeling reluctant to training but would end up winning the motm
# {'neg': 0.071, 'neu': 0.792, 'pos': 0.136, 'compound': 0.5852}
# honestly i've never seen such pass before cole palmer cold face cold face cold face
# {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.4588}
# cole palmer is like mvp russell westbrook - love him though
# {'neg': 0.0, 'neu': 0.544, 'pos': 0.456, 'compound': 0.7717}
# that’s why he’s called cole palmer innit?
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer knew his self-worth from a young age. fire fire fire
# {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'compound': -0.7351}
# cole palmer cross mark too easy check mark button
# {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.4404}
# with cole palmer all things are possible
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# he is not a new pep, mourinho, ancelotti, etc. like our cole palmer, he is our enzo maresca! blue heart
# {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'compound': 0.4199}
# manager of the month for sure cole palmer player of the month both people have carried this club cold face fire
# {'neg': 0.101, 'neu': 0.802, 'pos': 0.097, 'compound': -0.0258}
# con todo cole palmer
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# maresca - manager of the month! cole palmer - player of the month! cold face handshake
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# enzo maresca~ manager of the month ~ cole palmer ~ player of the month ~ cole palmer free kick or christopher nkunku goal against bournemouth goal of the month and sanchez penalty save~ save of the month
# {'neg': 0.074, 'neu': 0.765, 'pos': 0.16, 'compound': 0.5423}
# manager of the month- enzo maresca. player of the month- cole palmer. goal of the month- cole palmer.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# chelsea won 3 and cole palmer won 1
# {'neg': 0.0, 'neu': 0.351, 'pos': 0.649, 'compound': 0.8126}
# manager of the month september cole palmer player of the month september
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer is rebuilding this great club!
# {'neg': 0.0, 'neu': 0.537, 'pos': 0.463, 'compound': 0.7325}
# manager of the month for enzo maresca and player of the month for cole palmer no doubt fire
# {'neg': 0.321, 'neu': 0.679, 'pos': 0.0, 'compound': -0.7269}
# september enzo maresca coach of the month, cole palmer player of the month, cole palmer goal of the month raising hands fire
# {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'compound': -0.34}
# i wish england will hire southgate and fire him again for not starting cole palmer in 7 straight matches in euros
# {'neg': 0.104, 'neu': 0.696, 'pos': 0.2, 'compound': 0.296}
# when cole palmer scored that freekick goal the first person that came into my mind was marcos alonso
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer own is way far than alonso what a player face with tears of joy
# {'neg': 0.102, 'neu': 0.695, 'pos': 0.203, 'compound': 0.4404}
# everybody loves cole palmer cold face blue heart
# {'neg': 0.0, 'neu': 0.654, 'pos': 0.346, 'compound': 0.5719}
# god bless the scout behind he had been more than a blessing to us clapping hands crying face any injury that wants to happen to cole palmer should happen to mount and rashford amen clapping hands raising hands fire
# {'neg': 0.171, 'neu': 0.657, 'pos': 0.172, 'compound': 0.0202}
# cole palmer for a reason blue heart blue heart blue heart raising hands raising hands blue heart blue circle blue circle blue circle large blue diamond large blue diamond sparkles sparkles sparkles sparkles
# {'neg': 0.0, 'neu': 0.65, 'pos': 0.35, 'compound': 0.9001}
# admin please am a chelsea fan from nigeria iand i want to come and watch cole palmer live at stamford bridge
# {'neg': 0.0, 'neu': 0.731, 'pos': 0.269, 'compound': 0.5994}
# amazing player cole palmer, his presence gives everyone confidence even the fans
# {'neg': 0.0, 'neu': 0.585, 'pos': 0.415, 'compound': 0.7964}
# god bless who scouted cole palmer and confused chelsea to sign him
# {'neg': 0.142, 'neu': 0.556, 'pos': 0.302, 'compound': 0.3818}
# the thing i noticed about cole palmer is that he makes the other boys want to play better, he raises the morale, his performances are like a team talk
# {'neg': 0.0, 'neu': 0.717, 'pos': 0.283, 'compound': 0.7964}
# it’s cole palmer
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# who is cole palmer? for the blind, he is the vision. for the hungry, he is the chef. for the thirsty, he is the water. if palmer thinks, i agree. if palmer speaks, i'm listening. if palmer has one fan, it is me. if palmer has no fans, i don't exist blue circle blue circle blue circle
# {'neg': 0.079, 'neu': 0.81, 'pos': 0.11, 'compound': 0.2263}
# thank you man city for cole palmer!!! returning the favour we did when kevin de bruyne went the other way.
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.7412}
# clapping hands clapping hands cole palmer is the best player in the english league
# {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.6369}
# hi chelsea fans , do you know that cole palmer might end up being the best player to ever play for our club , forget that it's happening in our time .
# {'neg': 0.055, 'neu': 0.754, 'pos': 0.191, 'compound': 0.6908}
# we need win this league to show cole palmer to the world
# {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.5859}
# all thanks to cole palmer he has putting smiles back on our faces clapping hands red heart
# {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.7184}
# city took kevin de bruyne and the blues take cole palmer back smiling face
# {'neg': 0.0, 'neu': 0.812, 'pos': 0.188, 'compound': 0.4588}
# congratulations cole palmer, star player setting records and breaking records that's what cristiano ronaldo and lionel messi
# {'neg': 0.0, 'neu': 0.804, 'pos': 0.196, 'compound': 0.5994}
# cole palmer scored 3 hat-tricks or just two ?one against manchester united and another against brighton , or am i missing something?
# {'neg': 0.098, 'neu': 0.76, 'pos': 0.141, 'compound': 0.2406}
# even hazard didn’t even score 3 hattrick and cole palmer did it clapping hands medium-light skin tone such genius player blue heart hundred points
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole is cole palmer greatest of all time player chelsea fire clapping hands
# {'neg': 0.136, 'neu': 0.625, 'pos': 0.239, 'compound': 0.4215}
# thank god for cole palmer red heart snowflake snowflake
# {'neg': 0.0, 'neu': 0.603, 'pos': 0.397, 'compound': 0.5574}
# cole palmer already a chelsea legend
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer will defo create his own class soon
# {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.2732}
# madrid pls do not come for ice cole palmer pls cold face .
# {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.1531}
# world best at the moment cole palmer blue heart blue heart blue heart
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.6369}
# sniper fire by cole palmer double exclamation mark sounds like a new aftershave to me. go the blues! clinking beer mugs thumbs up vulcan salute
# {'neg': 0.088, 'neu': 0.809, 'pos': 0.103, 'compound': 0.1007}
# a chance for cole palmer, cole palmer scores.. that's how it is all the time. he will conveniently score 5 out of 5 if he isn't unlucky. not jackson who is supposed to be the clinical finisher. they all should learn how to be clinical from cole, but instead they try to beef, especially that bum called madueke. just because he scored 3 he thinks he's arrived and he actually knows next to nothing. palmer scores not because palmer is try to score, he just focuses on his positioning and makes use of the opportunity that comes as best as he could. he also passes when necessary
# {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'compound': 0.9001}
# cole palmer is everything he thinks he is blue heart
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# lucky enough to watch us get that win at the stadium.. cole palmer cold face
# {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.765}
# cole palmer finding the net without looking astonished face what a player cold face blue heart
# {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.2924}
# something happened where we watched the match between chelsea and brighton yesterday. after the first half, a chelsea fan who missed the first half of the match entered the viewing centre to watch the second half of the match was shocked that chelsea are already winning 4-2. when he saw the scoreline, he said “chelsea take am easy na” while walking to a spot to find a space to sit, he asked, “who scored the first goal for chelsea”every shouted “cole palmer” he asked again, the second one everyone shouted again, cole palmer. he asked the third one nko, everyone shouted again, cole palmer (in rhythmic synchrony)he then said okay, the 4th one, everyone again shouted “cole palmer” bro went crazy, pulled his shirt, and started running up and down the viewing centre shouting chelsea!!! chelsea!! chelsea!! (while other fans responded with “for life!!”)the joy and happiness cole palmer brought to chelsea since his signing will remain unmatchable in the history of the club. i bless the day we signed this guy. incredible stuff!
# {'neg': 0.037, 'neu': 0.848, 'pos': 0.116, 'compound': 0.9429}
# cole palmer is the debt paid by city for kdb
# {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.3612}
# ice cold cole palmer, there’s nothing he can not do clapping hands fire
# {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.34}
# who is cole palmer cold face cold face ? for the blind face with spiral eyes , he is the vision eyes . for the hungry tired face , he is the chef man cook medium skin tone . for the thirsty upside-down face , he is the water potable water . if palmer thinks thinking face , i agree. if palmer speaks face with open mouth , i'm listening ear with hearing aid medium-dark skin tone . if palmer has one fan, it is me. if palmer has no fans, i don't exist. blue heart blue heart
# {'neg': 0.082, 'neu': 0.846, 'pos': 0.072, 'compound': -0.25}
# please cole palmer deserve's the captain band blue heart
# {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.3182}
# something happened where we watched the match between chelsea and brighton yesterday. after the first half, a chelsea fan who missed the first half of the match entered the viewing centre to watch the second half of the match was shocked that chelsea are already winning 4-2. when he saw the scoreline, he said “chelsea take am easy na” while walking to a spot to find a space to sit, he asked, “who scored the first goal for chelsea”every shouted “cole palmer” he asked again, the second one everyone shouted again, cole palmer. he asked the third one nko, everyone shouted again, cole palmer (in rhythmic synchrony)he then said okay, the 4th one, everyone again shouted “cole palmer” bro went crazy, pulled his shirt, and started running up and down the viewing centre shouting chelsea!!! chelsea!! chelsea!! (while other fans responded with “for life!!”)the joy and happiness brought to chelsea since his signing will remain unmatchable in the history of the club. i bless the day we signed this guy. incredible stuff!
# {'neg': 0.037, 'neu': 0.846, 'pos': 0.117, 'compound': 0.9429}
# god is using cole palmer to put smile in every chelsea fan face and joy in our heart
# {'neg': 0.0, 'neu': 0.567, 'pos': 0.433, 'compound': 0.8658}
# cole palmer is a future world best
# {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}
# cole palmer cold face their is nothing he cannot do
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# player of the month cole palmer manager of the month enzo maresca goal of the month cole palmer
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# we need peter drury commentary on cole palmer blue heart blue heart blue heart face with tears of joy face with tears of joy face with tears of joy
# {'neg': 0.142, 'neu': 0.574, 'pos': 0.284, 'compound': 0.8271}
# ice cold cole palmer fire
# {'neg': 0.375, 'neu': 0.625, 'pos': 0.0, 'compound': -0.34}
# gonna tell my kids i was blessed to watch cole palmer in his prime. cold face cold face cold face cold face cold face cold face cold face cold face cold face cold face blue heart cold face blue heart magnet magnet magnet
# {'neg': 0.0, 'neu': 0.913, 'pos': 0.087, 'compound': 0.5994}
# that's why they call him cole palmer innit!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer blue heart give him a lifetime contract face with tears of joy blue heart
# {'neg': 0.102, 'neu': 0.695, 'pos': 0.203, 'compound': 0.4404}
# cole palmer and sancho’s performance from yesterday’s match was just extraordinary in everything. if maresca use these two players, i believe they will come up with something on the table.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# he a genius cold face . cole palmer is star boy fire
# {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'compound': -0.34}
# our very own cole palmer blue heart blue heart blue heart
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer is hungry
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# other chelsea man don't need to justify their price tag because cole palmer is coverig it all up. we will be back to lifting trophies soon when it all comes cool fire clapping hands
# {'neg': 0.065, 'neu': 0.872, 'pos': 0.063, 'compound': -0.0258}
# cole palmer is the reincarnation of eden hazard blue heart
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# premier league goals this season man utd 5 cole palmer 6 face with tears of joy
# {'neg': 0.107, 'neu': 0.678, 'pos': 0.215, 'compound': 0.4404}
# “cole palmer there’s nothing he cannot do” cold face
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# told my barista to make my coffee like cole palmer cold face
# {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.3612}
# our england england team golden boy cole palmer
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# for the blind, he is the vision. for the hungry, he is the chef. when he thinks, i agree & when he speaks, i listen. cole palmer, thank you for everything. folded hands medium skin tone loudly crying face
# {'neg': 0.132, 'neu': 0.708, 'pos': 0.16, 'compound': 0.0516}
# blue heart blue heart blue heart blue heart cole palmer you are the best.
# {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.6369}
# blue heart blue heart blue heart cole palmer
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# the commentator said “cole palmer there’s nothing he cannot do” clapping hands cold face blue heart
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer, there is nothing he cannot do
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# even cole palmer have free kick goal. still mbappe and haaland doesn't have one hundred points
# {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5106}
# it was cole palmer vs sanchez. congrats to our number one player and the history writer cold palmer. the world not going to forget this name forever. clapping hands medium-dark skin tone clapping hands medium-dark skin tone clapping hands medium-dark skin tone clapping hands medium-dark skin tone clapping hands medium-dark skin tone well done chelsea
# {'neg': 0.0, 'neu': 0.858, 'pos': 0.142, 'compound': 0.7555}
# “but it is cole palmer over the ball” cold face cold face cold face
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer to go liverpool urgent! cold face fire
# {'neg': 0.234, 'neu': 0.609, 'pos': 0.157, 'compound': -0.2244}
# who is cole palmer? for the blind, he is the vision. for the hungry, he is the chef. for the thirsty, he is the water. if palmer thinks, i agree. if palmer speaks, i'm listening. if palmer has one fan, it is me. if palmer has no fans, i don't exist. blue heart
# {'neg': 0.085, 'neu': 0.797, 'pos': 0.118, 'compound': 0.2263}
# cold face cole palmer is cold as ice cold face cold face cold face
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer player of the month 5 goals in the month of september and cole palmer goal of the month of september i'f anyone else takes it that robbery
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer, there is nothing he cannot do fire fire absolutely nothing cold face cold face blue heart blue heart blue heart blue heart
# {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'compound': 0.4717}
# hazard has been reborn in cole palmer blue heart blue heart blue heart blue heart blue heart
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer there’s nothing he cannot do in football but only god can do all
# {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.3919}
# cole palmer - "there's nothing he cannot do" blue heart blue heart blue heart
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# colder then cold that cole palmer cold face cold face
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer! there’s nothing he can not do clapping hands
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# commentator cole palmer! there is nothing he cannot do clapping hands
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer, there is nothing he can not do face with tears of joy blue heart
# {'neg': 0.096, 'neu': 0.711, 'pos': 0.193, 'compound': 0.4404}
# "cole palmer there's nothing he can not do"
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer - there is nothing he cannot do cold face
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer. there’s nothing he cannot do cold face
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# the first record made by young gen z cole palmer deserve more goals in premier league raising hands face with tears of joy blue heart blue heart blue heart blue heart
# {'neg': 0.056, 'neu': 0.831, 'pos': 0.113, 'compound': 0.4404}
# great player cole palmer blue heart
# {'neg': 0.0, 'neu': 0.549, 'pos': 0.451, 'compound': 0.6249}
# cole palmer you rock my world
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer the baller red heart
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer is the way, the truth and the life! blue heart blue heart blue heart
# {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.3802}
# from mexico bandera méxico te quiero mucho cole palmer cara con frío cara con frío cara con frío
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cole palmer is the best on earth
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.6369}
# eminem, phil foden, cole palmer...they are have conecction
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
from transformers import pipeline
import tensorflow

# %%
# create pipeline for sentiment analysis
classification = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %%
sentiment_analyis = []
for comment in comments_list:
    classify = classification(comment)
    sentiment_comment = {
        "comment": comment,
        "sentiment-analyis": classify
    }
    sentiment_analyis.append(sentiment_comment)

# %%
print(sentiment_analyis)
# Out:
# [{'comment': 'congratulations cole palmer, do it again, again, again, again snowflake snowflake snowflake', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.999714195728302}]}, {'comment': 'it’s the way cole palmer drifted into midfield position from an attacking position to make this sublime pass for me.. if you watched the earlier build up play. his football iq is on hundred points check mark button saluting face', 'sentiment-analyis': [{'label': 'NEGATIVE', 'score': 0.9151161313056946}]}, {'comment': 'thank you cole palmer for restoring the pride of london! cold face blue heart clapping hands dark skin tone i am beginning to recognise my club again!!!', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9995802044868469}]}, {'comment': 'cole palmer.. the next eh 10', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9084388613700867}]}, {'comment': 'brilliant cole palmer cold face blue heart blue heart', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9835228323936462}]}, {'comment': 'nj is a fantastic footballer. his runs and movements is awesome. cole palmer legend', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9998687505722046}]}, {'comment': 'damn cole palmer would be winning the best player award if not for people pulling him down', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9348403811454773}]}, {'comment': 'this boy cole palmer is so cool cold face fire', 'sentiment-analyis': [{'label': 'NEGATIVE', 'score': 0.7931884527206421}]}, {'comment': 'cole palmer - a delight to watch!! blue heart blue heart blue heart', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9998856782913208}]}, {'comment': 'am i the only one smiling smiling face with smiling eyes star-struck while looking at this pass from cole palmer face with peeking eye blue heart blue heart blue heart', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9979701638221741}]}, {'comment': 'mancity academy player cole palmer', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9944633841514587}]}, {'comment': 'cole palmer our joy giver star-struck blue heart jackson never disappoints btw face holding back tears', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.999680757522583}]}, {'comment': 'chelsea football club does not deserve cole palmer crying face', 'sentiment-analyis': [{'label': 'NEGATIVE', 'score': 0.9987688660621643}]}, {'comment': 'jackson was just rendering the assist efforts of cole palmer useless...jackson why?', 'sentiment-analyis': [{'label': 'NEGATIVE', 'score': 0.999796450138092}]}, {'comment': 'if cole palmer plays with real strikers man will have hundreds assists in one season', 'sentiment-analyis': [{'label': 'NEGATIVE', 'score': 0.9652131795883179}]}, {'comment': 'cole palmer has given admin a whole lot of content for the entire week!man doesn’t need to look into his archives face with tears of joy face with tears of joy rolling on the floor laughing rolling on the floor laughing', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9991514682769775}]}, {'comment': "does this cole palmer even train? because i hardly see him train with others. all chelsea legends often don't like training with others, even eden hazard. he was feeling reluctant to training but would end up winning the motm", 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9722050428390503}]}, {'comment': "honestly i've never seen such pass before cole palmer cold face cold face cold face", 'sentiment-analyis': [{'label': 'NEGATIVE', 'score': 0.9981998205184937}]}, {'comment': 'cole palmer is like mvp russell westbrook - love him though', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9985848665237427}]}, {'comment': 'that’s why he’s called cole palmer innit?', 'sentiment-analyis': [{'label': 'NEGATIVE', 'score': 0.9965972304344177}]}, {'comment': 'cole palmer knew his self-worth from a young age. fire fire fire', 'sentiment-analyis': [{'label': 'POSITIVE', 'score': 0.9962854385375977}]}, {'comment ...
